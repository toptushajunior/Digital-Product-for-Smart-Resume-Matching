# %%
import requests
import time
import os


class HHDownloader:
    """
    Downloads HTML pages witch contain links to resumes
    Automatically switch the pages by changing the page number in the link
    """
    def __init__(self, start_url_template: str, data_path: str, timeout=10):
        self.start_url_template = start_url_template
        self.headers = {'User-Agent':
                            'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
        self.timeout = timeout
        self.data_path = data_path

    def check_if_exists(self, page_num: int):
        """Check if the page was already downloaded"""
        return os.path.exists(os.path.join(self.data_path, 'resume_page_{0}.html'.format(page_num)))

    def download_pages(self, start_page: int, count: int):
        """"Starts the process of downloading pages in the specified range"""
        for page_num in range(count):
            if self.check_if_exists(start_page + page_num):
                print(f"File {'resume_page_{0}.html'.format(page_num)} already exists. Skip")
                continue
            print(f"Start downloading {page_num} page")
            page_url = self.get_page_url(page_num)
            print(f"Downloaded {page_num} page")
            page = self.download_page(page_url)
            self.save_page(page, start_page + page_num)
            print(f"Saved {page_num} page")
            print("*" * 20)
            time.sleep(self.timeout)

    def get_page_url(self, page_num: int):
        """Changes the page number in the link"""
        return self.start_url_template.format(page_num)

    def download_page(self, url: str):
        page = requests.get(url, headers=self.headers)
        return page

    def save_page(self, page, page_num: int):
        """Save the HTML page with page number in title to chosen directory"""
        page_file_name = os.path.join(self.data_path, 'resume_page_{0}.html'.format(page_num))
        with open(page_file_name, 'w') as resume_request:
            resume_request.write(page.text)


if __name__ == "__main__":
    #start_url = "https://hh.ru/search/resume?text=аналитик+данных&exp_period=all_time&ored_clusters=true&order_by=relevance&search_period=0&logic=normal&pos=full_text&page={0}"
    #start_url = "https://hh.ru/search/resume?text=Python+разработчик&from=suggest_post&pos=full_text&logic=normal&exp_period=all_time&ored_clusters=true&order_by=relevance&search_period=0&hhtmFrom=resume_search_result&hhtmFromLabel=resume_search_line&page={0}"
    #start_url = "https://hh.ru/search/resume?text=Java+разработчик&from=suggest_post&ored_clusters=true&order_by=relevance&search_period=0&logic=normal&pos=full_text&exp_period=all_time&hhtmFrom=resume_search_result&hhtmFromLabel=resume_search_line&page={0}"
    #start_url = "https://hh.ru/search/resume?text=Data+science&from=suggest_post&ored_clusters=true&order_by=relevance&search_period=0&logic=normal&pos=full_text&exp_period=all_time&hhtmFrom=resume_search_result&hhtmFromLabel=resume_search_line&page={0}"
    #start_url = "https://hh.ru/search/resume?text=Android+разработчик&from=suggest_post&ored_clusters=true&order_by=relevance&search_period=0&logic=normal&pos=full_text&exp_period=all_time&hhtmFrom=resume_search_result&hhtmFromLabel=resume_search_line&page={0}"
    #start_url = "https://hh.ru/search/resume?text=devops+инженер&ored_clusters=true&order_by=relevance&search_period=0&logic=normal&pos=full_text&exp_period=all_time&hhtmFrom=resume_search_result&hhtmFromLabel=resume_search_line&page={0}"
    #start_url = "https://hh.ru/search/resume?text=Ml+инженер&from=suggest_post&ored_clusters=true&order_by=relevance&search_period=0&logic=normal&pos=full_text&exp_period=all_time&hhtmFrom=resume_search_result&hhtmFromLabel=resume_search_line&page={0}"
    #start_url = "https://hh.ru/search/resume?text=ios-разработчик&ored_clusters=true&order_by=relevance&search_period=0&logic=normal&pos=full_text&exp_period=all_time&hhtmFrom=resume_search_result&hhtmFromLabel=resume_search_line&page={0}"
    #start_url = "https://hh.ru/search/resume?text=1-c+программист&ored_clusters=true&order_by=relevance&search_period=0&logic=normal&pos=full_text&exp_period=all_time&hhtmFrom=resume_search_result&hhtmFromLabel=resume_search_line&page={0}"
    start_url = "https://hh.ru/search/resume?text=Net+разработчик&from=suggest_post&ored_clusters=true&order_by=relevance&search_period=0&logic=normal&pos=full_text&exp_period=all_time&hhtmFrom=resume_search_result&hhtmFromLabel=resume_search_line&page={0}"
    hh_downloader = HHDownloader(start_url, "/content/drive/MyDrive/saved_html", timeout=20)
    hh_downloader.download_pages(108, 12)
# Out:
# Start downloading 0 page
# Downloaded 0 page
# Saved 0 page
# ********************
# Start downloading 1 page
# Downloaded 1 page
# Saved 1 page
# ********************
# Start downloading 2 page
# Downloaded 2 page
# Saved 2 page
# ********************
# Start downloading 3 page
# Downloaded 3 page
# Saved 3 page
# ********************
# Start downloading 4 page
# Downloaded 4 page
# Saved 4 page
# ********************
# Start downloading 5 page
# Downloaded 5 page
# Saved 5 page
# ********************
# Start downloading 6 page
# Downloaded 6 page
# Saved 6 page
# ********************
# Start downloading 7 page
# Downloaded 7 page
# Saved 7 page
# ********************
# Start downloading 8 page
# Downloaded 8 page
# Saved 8 page
# ********************
# Start downloading 9 page
# Downloaded 9 page
# Saved 9 page
# ********************
# Start downloading 10 page
# Downloaded 10 page
# Saved 10 page
# ********************
# Start downloading 11 page
# Downloaded 11 page
# Saved 11 page
# ********************

# %%
import re
from bs4 import BeautifulSoup


def write_links(page: str, pattern: str, start: int, end: int):
    """Осуществляет поиск ссылок на резюме в скаченных страницах"""
    for i in range(start, end + 1):
        with open(page.format(i), 'r') as resume_request, open('id_list.txt', 'a') as id_list:
            soup = BeautifulSoup(resume_request, features="lxml")
            for id_ls in soup.find_all("a",attrs={"class":"bloko-link", "data-qa":"serp-item__title"}):
              id_list.write(re.search(pattern, id_ls['href']).group(1))
              id_list.write('\n')

write_links('/content/drive/MyDrive/saved_html/resume_page_{0}.html', r'resume\/(.+)\?', 108, 119)

# %%
import requests
import time
import os


class HHResumeDownloader:
    """Класс предназначен для скачевания страниц резюме, при помощи списка уникальных ссылок на резюме"""
    def __init__(self, page_url: str, data_path: str, number: int, timeout=10):
        self.page_url = page_url
        self.headers = {'User-Agent':
                            'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
        self.timeout = timeout
        self.data_path = data_path
        self.number = number
        self.proxy = {'http': 'http://161.202.226.195:8123'}

    def check_if_exists(self, resume_id: str):
        """Функция проверяет, была ли уже скаченна данная странца"""
        return os.path.exists(os.path.join(self.data_path, f'resume_page_{resume_id}.html'))

    def get_page_url(self, resume_id: str):
        """Склеивает темплейт ссылки на резюме и уникальный номер страницы"""
        return self.page_url.format(resume_id)

    def download_pages(self):
        """Запускает процесс скачивания страниц"""
        with open('id_list.txt', 'r') as id_list:
            rep = 0
            for resume_id in id_list:
                resume_id = resume_id.strip()
                if self.check_if_exists(resume_id):
                    print(f"File {'resume_page_{0}.html'.format(resume_id)} already exists. Skip")
                    continue
                print(f"Start downloading {resume_id} page")
                page_url = self.get_page_url(resume_id)
                print(f"Downloaded {resume_id} page")
                page = self.download_page(page_url)
                self.save_page(page, resume_id)
                print(f"Saved {resume_id} page")
                print("*" * 20)
                time.sleep(self.timeout)
                rep += 1
                if self.number == rep:
                    break

    def download_page(self, url: str):
        """Скачивание страницы"""
        page = requests.get(url, headers=self.headers, proxies=self.proxy)
        return page

    def save_page(self, page, resume_id: str):
        """Сохранение страницы в папку"""
        page_file_name = os.path.join(self.data_path, 'resume_page_{0}.html'.format(resume_id))
        with open(page_file_name, 'w') as resume_request:
            resume_request.write(page.text)


if __name__ == "__main__":
    hh_resume_downloader = HHResumeDownloader("https://hh.ru/resume/{0}", "/content/drive/MyDrive/saved_resumes/", 2500, timeout=5)
    hh_resume_downloader.download_pages()
# Out:
# File resume_page_2324b9be0004f55e4c0039ed1f61387565664e.html already exists. Skip
# File resume_page_c776e49000090025c90039ed1f4c4374593469.html already exists. Skip
# File resume_page_2040886000082acbf30039ed1f696d51455a56.html already exists. Skip
# File resume_page_f99bfe92000930d3390039ed1f3435716e6c39.html already exists. Skip
# File resume_page_1cf286260008799ed00039ed1f4e734a553858.html already exists. Skip
# File resume_page_4d00443b00059949e30039ed1f61304f51786b.html already exists. Skip
# File resume_page_16c6569500087c34930039ed1f4d616b303762.html already exists. Skip
# File resume_page_59a2d49b0002ac9a650039ed1f657771484465.html already exists. Skip
# Downloaded d342dc9600070fba2f0039ed1f436741657677 page
# Saved d342dc9600070fba2f0039ed1f436741657677 page
# ********************
# Start downloading cb2e3f9c0006dc67a90039ed1f6666337a6550 page
# Downloaded cb2e3f9c0006dc67a90039ed1f6666337a6550 page
# Saved cb2e3f9c0006dc67a90039ed1f6666337a6550 page
# ********************
# Start downloading 255381940001f062c00039ed1f6957614a6841 page
# Downloaded 255381940001f062c00039ed1f6957614a6841 page
# Saved 255381940001f062c00039ed1f6957614a6841 page
# ********************
# Start downloading 571ff7da0001f6d5830039ed1f4b767a373950 page
# Downloaded 571ff7da0001f6d5830039ed1f4b767a373950 page
# Saved 571ff7da0001f6d5830039ed1f4b767a373950 page
# ********************
# Start downloading da370a0e0008efa4e40039ed1f6c654c355077 page
# Downloaded da370a0e0008efa4e40039ed1f6c654c355077 page
# Saved da370a0e0008efa4e40039ed1f6c654c355077 page
# ********************
# Start downloading f4f1f02c00085865b10039ed1f776f466d6c54 page
# Downloaded f4f1f02c00085865b10039ed1f776f466d6c54 page
# Saved f4f1f02c00085865b10039ed1f776f466d6c54 page
# ********************
# Start downloading a7b7e8280008e9cd040039ed1f3739306b6d63 page
# Downloaded a7b7e8280008e9cd040039ed1f3739306b6d63 page
# Saved a7b7e8280008e9cd040039ed1f3739306b6d63 page
# ********************
# Start downloading 44c5aba20008b98cc10039ed1f70426b314756 page
# Downloaded 44c5aba20008b98cc10039ed1f70426b314756 page
# Saved 44c5aba20008b98cc10039ed1f70426b314756 page
# ********************
# Start downloading f8e8a28b0001f29e830039ed1f323663713642 page
# Downloaded f8e8a28b0001f29e830039ed1f323663713642 page
# Saved f8e8a28b0001f29e830039ed1f323663713642 page
# ********************
# Start downloading 00dbccde00045555990039ed1f5a3266636452 page
# Downloaded 00dbccde00045555990039ed1f5a3266636452 page
# Saved 00dbccde00045555990039ed1f5a3266636452 page
# ********************
# Start downloading a01f847f00088acf6e0039ed1f31396830586b page
# Downloaded a01f847f00088acf6e0039ed1f31396830586b page
# Saved a01f847f00088acf6e0039ed1f31396830586b page
# ********************
# Start downloading d952add5000355ead50039ed1f416e69334848 page
# Downloaded d952add5000355ead50039ed1f416e69334848 page
# Saved d952add5000355ead50039ed1f416e69334848 page
# ********************
# Start downloading 1556baa9000934d83b0039ed1f4e6f68575962 page
# Downloaded 1556baa9000934d83b0039ed1f4e6f68575962 page
# Saved 1556baa9000934d83b0039ed1f4e6f68575962 page
# ********************
# Start downloading 6d78ef1100075b64180039ed1f52724f524239 page
# Downloaded 6d78ef1100075b64180039ed1f52724f524239 page
# Saved 6d78ef1100075b64180039ed1f52724f524239 page
# ********************
# Start downloading 829f8cdb0002bb96d90039ed1f797631756465 page
# Downloaded 829f8cdb0002bb96d90039ed1f797631756465 page
# Saved 829f8cdb0002bb96d90039ed1f797631756465 page
# ********************
# Start downloading 4255a53c000320111a0039ed1f6147637a4330 page
# Downloaded 4255a53c000320111a0039ed1f6147637a4330 page
# Saved 4255a53c000320111a0039ed1f6147637a4330 page
# ********************
# Start downloading 6c9810110003cbc64a0039ed1f7641484e384e page
# Downloaded 6c9810110003cbc64a0039ed1f7641484e384e page
# Saved 6c9810110003cbc64a0039ed1f7641484e384e page
# ********************
# Start downloading 2b7bb1f200042506530039ed1f78744336484d page
# Downloaded 2b7bb1f200042506530039ed1f78744336484d page
# Saved 2b7bb1f200042506530039ed1f78744336484d page
# ********************
# Start downloading 70f839ae00024139330039ed1f497233336a4e page
# Downloaded 70f839ae00024139330039ed1f497233336a4e page
# Saved 70f839ae00024139330039ed1f497233336a4e page
# ********************
# Start downloading d03f23380005292ab60039ed1f52774a573634 page
# Downloaded d03f23380005292ab60039ed1f52774a573634 page
# Saved d03f23380005292ab60039ed1f52774a573634 page
# ********************
# Start downloading 566e55f40002eea2830039ed1f64514b4b4336 page
# Downloaded 566e55f40002eea2830039ed1f64514b4b4336 page
# Saved 566e55f40002eea2830039ed1f64514b4b4336 page
# ********************
# Start downloading 0d5ae10d0008e0750d0039ed1f6874636d445a page
# Downloaded 0d5ae10d0008e0750d0039ed1f6874636d445a page
# Saved 0d5ae10d0008e0750d0039ed1f6874636d445a page
# ********************
# Start downloading 768842a20004e3624e0039ed1f47655a396d59 page
# Downloaded 768842a20004e3624e0039ed1f47655a396d59 page
# Saved 768842a20004e3624e0039ed1f47655a396d59 page
# ********************
# Start downloading 81e80e9b000635ec0c0039ed1f543750595071 page
# Downloaded 81e80e9b000635ec0c0039ed1f543750595071 page
# Saved 81e80e9b000635ec0c0039ed1f543750595071 page
# ********************
# Start downloading 9956576d0008866a470039ed1f684e49545162 page
# Downloaded 9956576d0008866a470039ed1f684e49545162 page
# Saved 9956576d0008866a470039ed1f684e49545162 page
# ********************
# Start downloading 5cdb7fe00008718aa80039ed1f754439664439 page
# Downloaded 5cdb7fe00008718aa80039ed1f754439664439 page
# Saved 5cdb7fe00008718aa80039ed1f754439664439 page
# ********************
# Start downloading 8f3424e40005ca47310039ed1f583641713871 page
# Downloaded 8f3424e40005ca47310039ed1f583641713871 page
# Saved 8f3424e40005ca47310039ed1f583641713871 page
# ********************
# Start downloading 7e9b84cc0001413c9c0039ed1f5a7175424778 page
# Downloaded 7e9b84cc0001413c9c0039ed1f5a7175424778 page
# Saved 7e9b84cc0001413c9c0039ed1f5a7175424778 page
# ********************
# Start downloading 9e1ff26a0008f1c7760039ed1f655356416749 page
# Downloaded 9e1ff26a0008f1c7760039ed1f655356416749 page
# Saved 9e1ff26a0008f1c7760039ed1f655356416749 page
# ********************
# Start downloading 679e3447000926b2f20039ed1f334f35554677 page
# Downloaded 679e3447000926b2f20039ed1f334f35554677 page
# Saved 679e3447000926b2f20039ed1f334f35554677 page
# ********************
# Start downloading ca714f7c000103e94a0039ed1f745255526c6d page
# Downloaded ca714f7c000103e94a0039ed1f745255526c6d page
# Saved ca714f7c000103e94a0039ed1f745255526c6d page
# ********************
# Start downloading 100f084000088f4d5b0039ed1f517170726430 page
# Downloaded 100f084000088f4d5b0039ed1f517170726430 page
# Saved 100f084000088f4d5b0039ed1f517170726430 page
# ********************
# Start downloading 4096fb890004e1d24c0039ed1f57734b317a37 page
# Downloaded 4096fb890004e1d24c0039ed1f57734b317a37 page
# Saved 4096fb890004e1d24c0039ed1f57734b317a37 page
# ********************
# Start downloading a93df86c0008a9cbc60039ed1f6f304a644739 page
# Downloaded a93df86c0008a9cbc60039ed1f6f304a644739 page
# Saved a93df86c0008a9cbc60039ed1f6f304a644739 page
# ********************
# Start downloading 3f8cd9670005cf4e590039ed1f346f55733969 page
# Downloaded 3f8cd9670005cf4e590039ed1f346f55733969 page
# Saved 3f8cd9670005cf4e590039ed1f346f55733969 page
# ********************
# Start downloading aba0b5dc0004a9be7d0039ed1f5868416b4d36 page
# Downloaded aba0b5dc0004a9be7d0039ed1f5868416b4d36 page
# Saved aba0b5dc0004a9be7d0039ed1f5868416b4d36 page
# ********************
# Start downloading 4acf0b49000844f6c80039ed1f395458353251 page
# Downloaded 4acf0b49000844f6c80039ed1f395458353251 page
# Saved 4acf0b49000844f6c80039ed1f395458353251 page
# ********************
# Start downloading 0d1d5f260001c67c7b0039ed1f67435a385150 page
# Downloaded 0d1d5f260001c67c7b0039ed1f67435a385150 page
# Saved 0d1d5f260001c67c7b0039ed1f67435a385150 page
# ********************
# Start downloading cf18c8200008898d780039ed1f58795a77524d page
# Downloaded cf18c8200008898d780039ed1f58795a77524d page
# Saved cf18c8200008898d780039ed1f58795a77524d page
# ********************
# Start downloading 2137d34a00014cef7d0039ed1f4a30416b7570 page
# Downloaded 2137d34a00014cef7d0039ed1f4a30416b7570 page
# Saved 2137d34a00014cef7d0039ed1f4a30416b7570 page
# ********************
# Start downloading 3fbebc6d0000b185310039ed1f736563726574 page
# Downloaded 3fbebc6d0000b185310039ed1f736563726574 page
# Saved 3fbebc6d0000b185310039ed1f736563726574 page
# ********************
# Start downloading e24ed8d400061b0f6d0039ed1f783675735151 page
# Downloaded e24ed8d400061b0f6d0039ed1f783675735151 page
# Saved e24ed8d400061b0f6d0039ed1f783675735151 page
# ********************
# Start downloading b2d43d18000835703d0039ed1f674d654a4338 page
# Downloaded b2d43d18000835703d0039ed1f674d654a4338 page
# Saved b2d43d18000835703d0039ed1f674d654a4338 page
# ********************
# Start downloading aa4f232d0008ae80730039ed1f6b536f59435a page
# Downloaded aa4f232d0008ae80730039ed1f6b536f59435a page
# Saved aa4f232d0008ae80730039ed1f6b536f59435a page
# ********************
# Start downloading a947a92e00037fc6190039ed1f506b4172624a page
# Downloaded a947a92e00037fc6190039ed1f506b4172624a page
# Saved a947a92e00037fc6190039ed1f506b4172624a page
# ********************
# Start downloading afc01d0c00026a22d60039ed1f4e7a34487433 page
# Downloaded afc01d0c00026a22d60039ed1f4e7a34487433 page
# Saved afc01d0c00026a22d60039ed1f4e7a34487433 page
# ...
# ********************
# Start downloading 4e1aef8f0008b5dbc70039ed1f653245375646 page
# Downloaded 4e1aef8f0008b5dbc70039ed1f653245375646 page
# Saved 4e1aef8f0008b5dbc70039ed1f653245375646 page
# ********************
# Start downloading d29c55570001e18a3b0039ed1f7a4a42726351 page
# Downloaded d29c55570001e18a3b0039ed1f7a4a42726351 page
# Saved d29c55570001e18a3b0039ed1f7a4a42726351 page
# ********************
# Start downloading 9cfb669f00071914130039ed1f426b6c45565a page
# Downloaded 9cfb669f00071914130039ed1f426b6c45565a page
# Saved 9cfb669f00071914130039ed1f426b6c45565a page
# ********************
# Start downloading 2d5be6b7000821bf180039ed1f505178557064 page
# Downloaded 2d5be6b7000821bf180039ed1f505178557064 page
# Saved 2d5be6b7000821bf180039ed1f505178557064 page
# ********************
# Start downloading 58a6338500034fa2960039ed1f66474f474f33 page
# Downloaded 58a6338500034fa2960039ed1f66474f474f33 page
# Saved 58a6338500034fa2960039ed1f66474f474f33 page
# ********************
# Start downloading 2d890654000311beb10039ed1f7a3449425141 page
# Downloaded 2d890654000311beb10039ed1f7a3449425141 page
# Saved 2d890654000311beb10039ed1f7a3449425141 page
# ********************
# Start downloading 51cff5ba0004006c240039ed1f545550695a35 page
# Downloaded 51cff5ba0004006c240039ed1f545550695a35 page
# Saved 51cff5ba0004006c240039ed1f545550695a35 page
# ********************
# Start downloading 6bb6866300061255320039ed1f34444f4b3236 page
# Downloaded 6bb6866300061255320039ed1f34444f4b3236 page
# Saved 6bb6866300061255320039ed1f34444f4b3236 page
# ********************
# Start downloading 8ef2ac3800016eea1f0039ed1f396963697344 page
# Downloaded 8ef2ac3800016eea1f0039ed1f396963697344 page
# Saved 8ef2ac3800016eea1f0039ed1f396963697344 page
# ********************
# Start downloading 719043fb0008560b5a0039ed1f6e3265734958 page
# Downloaded 719043fb0008560b5a0039ed1f6e3265734958 page
# Saved 719043fb0008560b5a0039ed1f6e3265734958 page
# ********************
# Start downloading 5175c2770000dafa360039ed1f7a75486a4852 page
# Downloaded 5175c2770000dafa360039ed1f7a75486a4852 page
# Saved 5175c2770000dafa360039ed1f7a75486a4852 page
# ********************
# File resume_page_c65c8b1b0008c63f650039ed1f715273394b38.html already exists. Skip
# Start downloading 511d6b890001eee3d20039ed1f754269573542 page
# Downloaded 511d6b890001eee3d20039ed1f754269573542 page
# Saved 511d6b890001eee3d20039ed1f754269573542 page
# ********************
# Start downloading 82a3ecb200006ae9040039ed1f736563726574 page
# Downloaded 82a3ecb200006ae9040039ed1f736563726574 page
# Saved 82a3ecb200006ae9040039ed1f736563726574 page
# ********************
# Start downloading 1a98fa0300070f59d10039ed1f396c4a63316c page
# Downloaded 1a98fa0300070f59d10039ed1f396c4a63316c page
# Saved 1a98fa0300070f59d10039ed1f396c4a63316c page
# ********************
# Start downloading 9ced1587000884cb4d0039ed1f5149476d4e70 page
# Downloaded 9ced1587000884cb4d0039ed1f5149476d4e70 page
# Saved 9ced1587000884cb4d0039ed1f5149476d4e70 page
# ********************
# Start downloading bdc9afd50008118a540039ed1f776153644d41 page
# Downloaded bdc9afd50008118a540039ed1f776153644d41 page
# Saved bdc9afd50008118a540039ed1f776153644d41 page
# ********************
# Start downloading cd5584610001ad5ba50039ed1f623575766d75 page
# Downloaded cd5584610001ad5ba50039ed1f623575766d75 page
# Saved cd5584610001ad5ba50039ed1f623575766d75 page
# ********************
# Start downloading 12f2d51c0008ae06340039ed1f6b32376c7a37 page
# Downloaded 12f2d51c0008ae06340039ed1f6b32376c7a37 page
# Saved 12f2d51c0008ae06340039ed1f6b32376c7a37 page
# ********************
# Start downloading 96c141dd00075c86040039ed1f6a7950393952 page
# Downloaded 96c141dd00075c86040039ed1f6a7950393952 page
# Saved 96c141dd00075c86040039ed1f6a7950393952 page
# ********************
# Start downloading 940763fe00038a4f1f0039ed1f57504e343369 page
# Downloaded 940763fe00038a4f1f0039ed1f57504e343369 page
# Saved 940763fe00038a4f1f0039ed1f57504e343369 page
# ********************
# Start downloading a41ea1ce0005580dc60039ed1f7733436c3536 page
# Downloaded a41ea1ce0005580dc60039ed1f7733436c3536 page
# Saved a41ea1ce0005580dc60039ed1f7733436c3536 page
# ********************
# Start downloading 4de8618e0001ce10c30039ed1f437068463649 page
# Downloaded 4de8618e0001ce10c30039ed1f437068463649 page
# Saved 4de8618e0001ce10c30039ed1f437068463649 page
# ********************
# Start downloading f0b53c50000741e02f0039ed1f6942634b5333 page
# Downloaded f0b53c50000741e02f0039ed1f6942634b5333 page
# Saved f0b53c50000741e02f0039ed1f6942634b5333 page
# ********************
# Start downloading 0858b5b700040208db0039ed1f4e4357666d4f page
# Downloaded 0858b5b700040208db0039ed1f4e4357666d4f page
# Saved 0858b5b700040208db0039ed1f4e4357666d4f page
# ********************
# Start downloading f44959e600051847180039ed1f36434d32796b page
# Downloaded f44959e600051847180039ed1f36434d32796b page
# Saved f44959e600051847180039ed1f36434d32796b page
# ********************
# Start downloading 595fe9de00073f4ddc0039ed1f6c39414c506a page
# Downloaded 595fe9de00073f4ddc0039ed1f6c39414c506a page
# Saved 595fe9de00073f4ddc0039ed1f6c39414c506a page
# ********************
# File resume_page_9b4143d400062e1f430039ed1f745a4f425a35.html already exists. Skip
# Start downloading 833017d900022cc8be0039ed1f6b4d6f585262 page
# Downloaded 833017d900022cc8be0039ed1f6b4d6f585262 page
# Saved 833017d900022cc8be0039ed1f6b4d6f585262 page
# ********************
# Start downloading b1f15f6b0007e8c2ef0039ed1f663764787741 page
# Downloaded b1f15f6b0007e8c2ef0039ed1f663764787741 page
# Saved b1f15f6b0007e8c2ef0039ed1f663764787741 page
# ********************
# Start downloading 44ed1ee300088931e00039ed1f747a306e4e64 page
# Downloaded 44ed1ee300088931e00039ed1f747a306e4e64 page
# Saved 44ed1ee300088931e00039ed1f747a306e4e64 page
# ********************
# Start downloading e3fe8b0c0008f0cfac0039ed1f694e6756614b page
# Downloaded e3fe8b0c0008f0cfac0039ed1f694e6756614b page
# Saved e3fe8b0c0008f0cfac0039ed1f694e6756614b page
# ********************
# Start downloading dd9ab17200032b5b5f0039ed1f476d73486a39 page
# Downloaded dd9ab17200032b5b5f0039ed1f476d73486a39 page
# Saved dd9ab17200032b5b5f0039ed1f476d73486a39 page
# ********************
# Start downloading 1863b95900027a15770039ed1f736d6d7a424f page
# Downloaded 1863b95900027a15770039ed1f736d6d7a424f page
# Saved 1863b95900027a15770039ed1f736d6d7a424f page
# ********************
# Start downloading 2a9756cf0006ee85de0039ed1f756a63626174 page
# Downloaded 2a9756cf0006ee85de0039ed1f756a63626174 page
# Saved 2a9756cf0006ee85de0039ed1f756a63626174 page
# ********************
# Start downloading 871c9c690002da8b450039ed1f503171424168 page
# Downloaded 871c9c690002da8b450039ed1f503171424168 page
# Saved 871c9c690002da8b450039ed1f503171424168 page
# ********************
# Start downloading e0c924d00007abd2f50039ed1f556778645a4d page
# Downloaded e0c924d00007abd2f50039ed1f556778645a4d page
# Saved e0c924d00007abd2f50039ed1f556778645a4d page
# ********************
# Start downloading 3e9359e600008cc6d90039ed1f736563726574 page
# Downloaded 3e9359e600008cc6d90039ed1f736563726574 page
# Saved 3e9359e600008cc6d90039ed1f736563726574 page
# ********************
# Start downloading fc940d560001ffe1c40039ed1f503741667a53 page
# Downloaded fc940d560001ffe1c40039ed1f503741667a53 page
# Saved fc940d560001ffe1c40039ed1f503741667a53 page
# ********************
# Start downloading ecbb8c1f00069987990039ed1f785a45436d73 page
# Downloaded ecbb8c1f00069987990039ed1f785a45436d73 page
# Saved ecbb8c1f00069987990039ed1f785a45436d73 page
# ********************
# Start downloading 90b0a52c00025f21250039ed1f613474463664 page
# Downloaded 90b0a52c00025f21250039ed1f613474463664 page
# Saved 90b0a52c00025f21250039ed1f613474463664 page
# ********************
# Start downloading 61071bfc00074ccbc90039ed1f39536c736a78 page
# Downloaded 61071bfc00074ccbc90039ed1f39536c736a78 page
# Saved 61071bfc00074ccbc90039ed1f39536c736a78 page
# ********************
# Start downloading 24817f140008dc49900039ed1f694441624e37 page
# Downloaded 24817f140008dc49900039ed1f694441624e37 page
# Saved 24817f140008dc49900039ed1f694441624e37 page
# ********************
# Start downloading eaee0b9900041cb7480039ed1f416c68547643 page
# Downloaded eaee0b9900041cb7480039ed1f416c68547643 page
# Saved eaee0b9900041cb7480039ed1f416c68547643 page
# ********************
# Start downloading 3f818d450002931cb80039ed1f564e4c494b6c page
# Downloaded 3f818d450002931cb80039ed1f564e4c494b6c page
# Saved 3f818d450002931cb80039ed1f564e4c494b6c page
# ********************
# Start downloading ada74c700002e1e37c0039ed1f584251554842 page
# Downloaded ada74c700002e1e37c0039ed1f584251554842 page
# Saved ada74c700002e1e37c0039ed1f584251554842 page
# ********************
# Start downloading 0a9744200005a34f5f0039ed1f6134574d5578 page
# Downloaded 0a9744200005a34f5f0039ed1f6134574d5578 page
# Saved 0a9744200005a34f5f0039ed1f6134574d5578 page
# ********************
# Start downloading fc901c6500015051bb0039ed1f59566e493337 page
# Downloaded fc901c6500015051bb0039ed1f59566e493337 page
# Saved fc901c6500015051bb0039ed1f59566e493337 page
# ********************
# Start downloading aadcceb800024879580039ed1f4f304a537558 page
# Downloaded aadcceb800024879580039ed1f4f304a537558 page
# Saved aadcceb800024879580039ed1f4f304a537558 page
# ********************
# Start downloading 40f8b366000215ead00039ed1f635846753846 page
# Downloaded 40f8b366000215ead00039ed1f635846753846 page
# Saved 40f8b366000215ead00039ed1f635846753846 page
# ********************
# Start downloading 5819e7500008c364d50039ed1f664758454f4e page
# Downloaded 5819e7500008c364d50039ed1f664758454f4e page
# Saved 5819e7500008c364d50039ed1f664758454f4e page
# ********************
# Start downloading 63d8d65000066dd5b40039ed1f4b39686a4335 page
# Downloaded 63d8d65000066dd5b40039ed1f4b39686a4335 page
# Saved 63d8d65000066dd5b40039ed1f4b39686a4335 page
# ********************
# Start downloading 2459f60a0003d65d390039ed1f317339364135 page
# Downloaded 2459f60a0003d65d390039ed1f317339364135 page
# Saved 2459f60a0003d65d390039ed1f317339364135 page
# ********************
# Start downloading 604e57aa0001afab5c0039ed1f394879484738 page
# Downloaded 604e57aa0001afab5c0039ed1f394879484738 page
# Saved 604e57aa0001afab5c0039ed1f394879484738 page
# ********************
# Start downloading ffbcf023000392a0c90039ed1f6d687373634c page
# Downloaded ffbcf023000392a0c90039ed1f6d687373634c page
# Saved ffbcf023000392a0c90039ed1f6d687373634c page
# ********************
# Start downloading df8a375200031160990039ed1f57344d504d5a page
# Downloaded df8a375200031160990039ed1f57344d504d5a page
# Saved df8a375200031160990039ed1f57344d504d5a page
# ********************
# Start downloading a5da5ee900006f128e0039ed1f736563726574 page
# Downloaded a5da5ee900006f128e0039ed1f736563726574 page
# Saved a5da5ee900006f128e0039ed1f736563726574 page
# ********************
# Start downloading 8ebc5e1000009d88f80039ed1f736563726574 page
# Downloaded 8ebc5e1000009d88f80039ed1f736563726574 page
# Saved 8ebc5e1000009d88f80039ed1f736563726574 page
# ********************
# Start downloading 41ed020f00052d1a290039ed1f55526d67546b page
# Downloaded 41ed020f00052d1a290039ed1f55526d67546b page
# Saved 41ed020f00052d1a290039ed1f55526d67546b page
# ********************
# Start downloading 6ded6a73000833f82f0039ed1f527350576164 page
# Downloaded 6ded6a73000833f82f0039ed1f527350576164 page
# Saved 6ded6a73000833f82f0039ed1f527350576164 page
# ********************
# Start downloading 431c5ab400031f3c660039ed1f4d6451755858 page
# Downloaded 431c5ab400031f3c660039ed1f4d6451755858 page
# Saved 431c5ab400031f3c660039ed1f4d6451755858 page
# ********************
# Start downloading 16fe5c730005b329fe0039ed1f376655556275 page
# Downloaded 16fe5c730005b329fe0039ed1f376655556275 page
# Saved 16fe5c730005b329fe0039ed1f376655556275 page
# ********************
# Start downloading 88a11f8b0008e1fcb10039ed1f716a35686577 page
# Downloaded 88a11f8b0008e1fcb10039ed1f716a35686577 page
# Saved 88a11f8b0008e1fcb10039ed1f716a35686577 page
# ********************
# Start downloading 68e1c50500081299da0039ed1f747266423548 page
# Downloaded 68e1c50500081299da0039ed1f747266423548 page
# Saved 68e1c50500081299da0039ed1f747266423548 page
# ********************
# Start downloading 213c139f0007ce90ba0039ed1f49677057476d page
# Downloaded 213c139f0007ce90ba0039ed1f49677057476d page
# Saved 213c139f0007ce90ba0039ed1f49677057476d page
# ********************
# Start downloading 3e085c5e0000c8d6240039ed1f69555171354c page
# Downloaded 3e085c5e0000c8d6240039ed1f69555171354c page
# Saved 3e085c5e0000c8d6240039ed1f69555171354c page
# ********************
# Start downloading 3edd43100003f693350039ed1f68566b554935 page
# Downloaded 3edd43100003f693350039ed1f68566b554935 page
# Saved 3edd43100003f693350039ed1f68566b554935 page
# ********************
# Start downloading 4a3eb7bc0003c74bcf0039ed1f696f78386449 page
# Downloaded 4a3eb7bc0003c74bcf0039ed1f696f78386449 page
# Saved 4a3eb7bc0003c74bcf0039ed1f696f78386449 page
# ********************
# Start downloading 417183020004e988930039ed1f69715354464a page
# Downloaded 417183020004e988930039ed1f69715354464a page
# Saved 417183020004e988930039ed1f69715354464a page
# ********************
# Start downloading 452302f600087ef8130039ed1f445939744441 page
# Downloaded 452302f600087ef8130039ed1f445939744441 page
# Saved 452302f600087ef8130039ed1f445939744441 page
# ********************
# Start downloading c4584a2e000263380d0039ed1f514c37584c53 page
# Downloaded c4584a2e000263380d0039ed1f514c37584c53 page
# Saved c4584a2e000263380d0039ed1f514c37584c53 page
# ********************
# Start downloading e87c5b7200030ec0420039ed1f785545505a53 page
# Downloaded e87c5b7200030ec0420039ed1f785545505a53 page
# Saved e87c5b7200030ec0420039ed1f785545505a53 page
# ********************
# Start downloading e7a892fd000252a99a0039ed1f66364c376739 page
# Downloaded e7a892fd000252a99a0039ed1f66364c376739 page
# Saved e7a892fd000252a99a0039ed1f66364c376739 page
# ********************
# Start downloading 3a177971000882ac290039ed1f754445716e77 page
# Downloaded 3a177971000882ac290039ed1f754445716e77 page
# Saved 3a177971000882ac290039ed1f754445716e77 page
# ********************
# Start downloading aa1ac9350008b3ce6b0039ed1f746a77506233 page
# Downloaded aa1ac9350008b3ce6b0039ed1f746a77506233 page
# Saved aa1ac9350008b3ce6b0039ed1f746a77506233 page
# ********************
# Start downloading d15e992d0002371d310039ed1f377137364b41 page
# Downloaded d15e992d0002371d310039ed1f377137364b41 page
# Saved d15e992d0002371d310039ed1f377137364b41 page
# ********************
# Start downloading 986fd2460001d1fbe80039ed1f4a4e7433434f page
# Downloaded 986fd2460001d1fbe80039ed1f4a4e7433434f page
# Saved 986fd2460001d1fbe80039ed1f4a4e7433434f page
# ********************
# Start downloading 435210870001912b950039ed1f69694f636176 page
# Downloaded 435210870001912b950039ed1f69694f636176 page
# Saved 435210870001912b950039ed1f69694f636176 page
# ********************
# Start downloading ecad8109000247a2f00039ed1f793146696e59 page
# Downloaded ecad8109000247a2f00039ed1f793146696e59 page
# Saved ecad8109000247a2f00039ed1f793146696e59 page
# ********************
# Start downloading ff3232d20006ebe48a0039ed1f66514e7a7341 page
# Downloaded ff3232d20006ebe48a0039ed1f66514e7a7341 page
# Saved ff3232d20006ebe48a0039ed1f66514e7a7341 page
# ********************
# Start downloading 95e4b9a20003a00ecb0039ed1f3751576c3649 page
# Downloaded 95e4b9a20003a00ecb0039ed1f3751576c3649 page
# Saved 95e4b9a20003a00ecb0039ed1f3751576c3649 page
# ********************
# Start downloading e6cb693e00081908010039ed1f41594b556172 page
# Downloaded e6cb693e00081908010039ed1f41594b556172 page
# Saved e6cb693e00081908010039ed1f41594b556172 page
# ********************
# Start downloading 146197990002034fb60039ed1f776f49734a49 page
# Downloaded 146197990002034fb60039ed1f776f49734a49 page
# Saved 146197990002034fb60039ed1f776f49734a49 page
# ********************
# Start downloading 0a45d0610005262f930039ed1f6866326a5454 page
# Downloaded 0a45d0610005262f930039ed1f6866326a5454 page
# Saved 0a45d0610005262f930039ed1f6866326a5454 page
# ********************
# Start downloading 889150150003ccef460039ed1f5a3363634d73 page
# Downloaded 889150150003ccef460039ed1f5a3363634d73 page
# Saved 889150150003ccef460039ed1f5a3363634d73 page
# ********************
# Start downloading 36acf189000602225e0039ed1f4b636a585839 page
# Downloaded 36acf189000602225e0039ed1f4b636a585839 page
# Saved 36acf189000602225e0039ed1f4b636a585839 page
# ********************

# %%
from bs4 import BeautifulSoup
import os
import re
#from googletrans import Translator
import json
import pandas as pd


class Resume:
    """Class extracts the resume information from HTML page"""
    def __init__(self, soup, resume_id):
        self.soup = soup
        self.resume_id = resume_id
        self.resume_title = self.extract_title()
        self.city = self.extract_information('span', {'data-qa': "resume-personal-address"})
        self.age = self.extract_age()
        self.gender = self.extract_gender
        self.area = self.extract_area()
        self.desired_wage = self.extract_wage()
        self.work_exp = self.extract_work_experience()
        self.education = self.extract_nested_information('div', {'data-qa': "resume-block-education"})
        self.language_prof = self.extract_languages()
        self.skills = self.extract_information('span', {'class': "bloko-tag__section bloko-tag__section_text"})
        self.university = self.extract_university('a', {'class':"bloko-link bloko-link_kind-tertiary"})
        self.faculty = self.extract_information('div', {'data-qa':"resume-block-education-organization"})
        self.work_exp_descr = self.extract_work_exp_descr()
        #self.dict_resume = self.resume_dict_maker()

    def __repr__(self):
        return f'{self.dict_resume}'

    def extract_title(self):
        title = self.extract_information('span', {'data-qa': "resume-block-title-position"})
        main_titles = title.split(',')
        main_title = main_titles[0]
        return main_title

    def extract_age(self):
        raw_age = self.extract_information('span', {'data-qa': "resume-personal-age"})
        digit_pattern = r'\d+'
        if raw_age != "No information":
            age = re.findall(digit_pattern, raw_age)
            age = age[0]
            return age
        else:
            return 0

    def extract_work_experience(self):
        work_exp = self.extract_nested_information('div', {'data-qa': "resume-block-experience"})
        float_pattern = r'\d+'  # Search for any digit in str
        if work_exp != "No information":
            work_exp = re.findall(float_pattern, work_exp) # Extract period of work from the str
            if len(work_exp) == 2:
                work_exp = round((int(work_exp[0]) + int(work_exp[0])/12), 2)
            elif len(work_exp) == 1:
                work_exp = round(int(work_exp[0])/12, 2)
            return work_exp
        else:
            return 0

    def extract_area(self):
        area = self.extract_information('li', {'class':"resume-block__specialization", 'data-qa':'resume-block-position-specialization'})
        return area

    def extract_wage(self):
        wage = self.extract_information('span', {'data-qa': "resume-block-salary"})
        int_pattern = r'\d'
        if wage != "No information":
            wage_amount = re.findall(int_pattern, wage)
            wage_str = ''.join(wage_amount)
            wage = int(f'{wage_str}')
            return wage
        else:
            return 0

    def extract_languages(self):
        languages = self.extract_information('p', {'data-qa': "resume-block-language-item"}, to_list=False)
        if type(languages) == str:  # If only one or no language stated in resume
            languages = {"Russian": "Native"}
        return languages

    @property
    def extract_gender(self):
        gender = self.extract_information('span', {'data-qa': "resume-personal-gender"})
        if gender == 'The man' or gender == 'Male':  # If translation inaccurate
            gender = 'Мужчина'
        elif gender == 'Woman' or gender == 'Female':
            gender = 'Женщина'
        return gender

    def extract_university(self, tag: str, attributes: dict):
        finder = self.soup.find_all(tag, attributes)
        if finder is None or len(finder) == 0:
            return "No information"
        else:
          st = set()
          for i in finder:
            if re.search(r'university=(.+)', i['href']):
              st.add(i.get_text())
          if len(st) == 0:
            return "No information"
          return list(st)

    def extract_work_exp_descr(self):
        finder1 = self.soup.find_all('a', {'class':"bloko-link bloko-link_kind-tertiary"})
        st = []
        for i in finder1:
          if re.search(r'employer', i['href']):
            st.append(i.get_text())

        finder2 = self.soup.find_all('div', {'data-qa':"resume-block-experience-position", 'class':"bloko-text bloko-text_strong"})
        st2 = []
        if len(finder2) == 1:
            st2.append(finder2[0].get_text())
        elif len(finder2) > 1:
          for part in finder2:
            list_element = part.get_text()
            st2.append(list_element)

        finder3 = self.soup.find_all('div', {'data-qa':"resume-block-experience-description"})
        st3 = []
        if len(finder3) == 1:
            st3.append(finder3[0].get_text())
        elif len(finder3) > 1:
          for part in finder3:
            list_element = part.get_text()
            st3.append(list_element)
        res = dict()
        for i in range(len(st)):
          res[st[i]] = [st2[i], st3[i]]
        if len(res) == 0:
          return 'No information'
        return res
    '''def check_for_translation(self, info):
        rus_pattern = r'[а-яА-Я]+'
        if re.search(rus_pattern, info):
            info = self.translator(info)
        return info'''

    '''@staticmethod
    def translator(text):  # If the resume is in Russian
        translator = Translator()
        result = translator.translate(text)
        return result.text'''

    def extract_information(self, tag: str, attributes: dict, to_list=True):
        finder = self.soup.find_all(tag, attributes)
        if len(finder) == 1:
            #finder = self.check_for_translation(finder[0].get_text())
            finder = finder[0].get_text()
            return finder
        elif len(finder) > 1:
            if to_list:
                listed_info = []
                for part in finder:
                    list_element = part.get_text()
                    #list_element = self.check_for_translation(list_element)
                    listed_info.append(list_element)
                return listed_info
            else:
                dict_info = {}
                for dict_part in finder:
                    dict_element = dict_part.get_text()
                    #dict_element = self.check_for_translation(dict_element)
                    splitted_dict_element = dict_element.split()
                    dict_info[splitted_dict_element[0]] = splitted_dict_element[2]
                return dict_info
        else:
            return "No information"

    def extract_nested_information(self, tag: str, attributes: dict, to_list=True):
        finder = self.soup.find(tag, attributes)
        if finder is None:
            return "No information"
        else:
            finder = finder.find('span', {'class': "resume-block__title-text resume-block__title-text_sub"})
            #finder = self.check_for_translation(finder.get_text())
            finder = finder.get_text()
        return finder

    def resume_dict_maker(self):
          resume_dict = {'id': self.resume_id,
                       'title': self.resume_title,
                       'city': self.city,
                       'age': self.age,
                       'gender': self.gender,
                       'area': self.area,
                       'desired_wage': self.desired_wage,
                       'work_experience': self.work_exp,
                       'work_exp_descr': self.work_exp_descr,
                       'education_level': self.education,
                       'university':self.university,
                       'faculty': self.faculty,
                       'languages': self.language_prof,
                       'skills': self.skills
                       }
          return resume_dict

# %%
class ResumeGetter:
    """Запускает процесс скачивания резюме"""
    def __init__(self):
        self.dir_path = "/content/drive/MyDrive/saved_resumes/"
        self.resume_storage = os.listdir(path=self.dir_path)
        self.resume_dict_storage = []

    def get_resume(self):
        for resume in self.resume_storage:
            with open(f'{self.dir_path}{resume}', "r") as resume_page:
                resume_text = BeautifulSoup(resume_page, features="lxml")
                resume_id = str(re.search(r"page_(.+)\.html", resume).group(1))  # забираем id из названия файла
                if self.check_if_exists(resume_id):
                    print(f"File {f'{resume_id}.json'} already exists. Skip")
                    continue
                print(f'Start parce {resume_id}')
                resume_getter = Resume(resume_text, resume_id)
                dict_format = resume_getter.resume_dict_maker()
                self.resume_dict_storage.append(dict_format)
                self.get_json_resume(dict_format, resume_id)
                print(f'Resume {resume_id} saved in json file')
                print('*' * 20)
        return self.resume_dict_storage

    def check_if_exists(self, res_id: str):
        """Проверка в списке загруженных файлов"""
        return os.path.exists(os.path.join('/content/drive/MyDrive/new_json_resumes/', f'{res_id}.json'))

    def get_json_resume(self, resume_dict: dict, r_id: str):
        """Сохраняет резюме в отдельный json-файл"""
        with open(f'/content/drive/MyDrive/new_json_resumes/{r_id}.json', 'w+') as json_file:
            json.dump(resume_dict, json_file, indent=4)

# %%
if __name__ == '__main__':
    data = ResumeGetter()
    all_resumes = data.get_resume()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Resume 49465e380001f869560039ed1f7a6b34563730 saved in json file
# ********************
# Start parce 764142e90004f005fb0039ed1f5a51727a3043
# Resume 764142e90004f005fb0039ed1f5a51727a3043 saved in json file
# ********************
# Start parce 395ea35b0004f1f85a0039ed1f36524a354941
# Resume 395ea35b0004f1f85a0039ed1f36524a354941 saved in json file
# ********************
# Start parce 90b24032000316f07a0039ed1f635044625367
# Resume 90b24032000316f07a0039ed1f635044625367 saved in json file
# ********************
# Start parce 99750348000264b3990039ed1f7a34736d4e36
# Resume 99750348000264b3990039ed1f7a34736d4e36 saved in json file
# ********************
# Start parce 385ec66100052df8470039ed1f48634b56716c
# Resume 385ec66100052df8470039ed1f48634b56716c saved in json file
# ********************
# Start parce ab58a700000278a2fa0039ed1f465071706178
# Resume ab58a700000278a2fa0039ed1f465071706178 saved in json file
# ********************
# Start parce 1723e580000810ff310039ed1f67437a6c4570
# Resume 1723e580000810ff310039ed1f67437a6c4570 saved in json file
# ********************
# Start parce a4ad6ff000076e03c10039ed1f3538666c7353
# Resume a4ad6ff000076e03c10039ed1f3538666c7353 saved in json file
# ********************
# Start parce a55e5c1800070620920039ed1f6a4e64586856
# Resume a55e5c1800070620920039ed1f6a4e64586856 saved in json file
# ********************
# Start parce 1c3415c900026b59490039ed1f313134715836
# Resume 1c3415c900026b59490039ed1f313134715836 saved in json file
# ********************
# Start parce 1b6aecdc0001fb9aba0039ed1f31745a646261
# Resume 1b6aecdc0001fb9aba0039ed1f31745a646261 saved in json file
# ********************
# Start parce 240165ee00020133b70039ed1f36564648796b
# Resume 240165ee00020133b70039ed1f36564648796b saved in json file
# ********************
# Start parce c6125d610006bf826d0039ed1f6f4836615569
# Resume c6125d610006bf826d0039ed1f6f4836615569 saved in json file
# ********************
# Start parce 54f6e2cb0001b02d220039ed1f4f59746c7877
# Resume 54f6e2cb0001b02d220039ed1f4f59746c7877 saved in json file
# ********************
# Start parce 2b85dbcd0001d2f36e0039ed1f626267586e71
# Resume 2b85dbcd0001d2f36e0039ed1f626267586e71 saved in json file
# ********************
# Start parce 747bb3c300041b4a0e0039ed1f4c6d51544348
# Resume 747bb3c300041b4a0e0039ed1f4c6d51544348 saved in json file
# ********************
# Start parce c1376ed70003232a940039ed1f31545232486f
# Resume c1376ed70003232a940039ed1f31545232486f saved in json file
# ********************
# Start parce 95112f2c0001ca30f90039ed1f6e304b7a4d4a
# Resume 95112f2c0001ca30f90039ed1f6e304b7a4d4a saved in json file
# ********************
# Start parce 01fb2735000215163b0039ed1f4539624f6158
# Resume 01fb2735000215163b0039ed1f4539624f6158 saved in json file
# ********************
# Start parce 680dd34b00054f6afe0039ed1f706762353744
# Resume 680dd34b00054f6afe0039ed1f706762353744 saved in json file
# ********************
# Start parce ebc4d46300050351870039ed1f436350587564
# Resume ebc4d46300050351870039ed1f436350587564 saved in json file
# ********************
# Start parce 2c2a43dd0002380cc60039ed1f7676535a7352
# Resume 2c2a43dd0002380cc60039ed1f7676535a7352 saved in json file
# ********************
# Start parce 545a8ec20000fe275c0039ed1f454f64746238
# Resume 545a8ec20000fe275c0039ed1f454f64746238 saved in json file
# ********************
# Start parce 654574be00050d38120039ed1f52334e643557
# Resume 654574be00050d38120039ed1f52334e643557 saved in json file
# ********************
# Start parce 198b7d290004173a780039ed1f686c45485055
# Resume 198b7d290004173a780039ed1f686c45485055 saved in json file
# ********************
# Start parce 27a735a500018bf7580039ed1f44655a694a6d
# Resume 27a735a500018bf7580039ed1f44655a694a6d saved in json file
# ********************
# Start parce 2fe0ef4c0006b52eba0039ed1f535851623335
# Resume 2fe0ef4c0006b52eba0039ed1f535851623335 saved in json file
# ********************
# Start parce 12b5211300032ee67a0039ed1f345671423444
# Resume 12b5211300032ee67a0039ed1f345671423444 saved in json file
# ********************
# Start parce 98483d260001f189eb0039ed1f6a5457416232
# Resume 98483d260001f189eb0039ed1f6a5457416232 saved in json file
# ********************
# Start parce b7ace9fb0002e705fe0039ed1f3955584f5250
# Resume b7ace9fb0002e705fe0039ed1f3955584f5250 saved in json file
# ********************
# Start parce 1280784b0000ac11fc0039ed1f736563726574
# Resume 1280784b0000ac11fc0039ed1f736563726574 saved in json file
# ********************
# Start parce e385fc5f0000be132a0039ed1f736563726574
# Resume e385fc5f0000be132a0039ed1f736563726574 saved in json file
# ********************
# Start parce 37bdfcc800079d1cc80039ed1f4a4348565555
# Resume 37bdfcc800079d1cc80039ed1f4a4348565555 saved in json file
# ********************
# Start parce cab63eb90001bfa1770039ed1f657953335468
# Resume cab63eb90001bfa1770039ed1f657953335468 saved in json file
# ********************
# Start parce f371a2290006d94ea10039ed1f525130454d47
# Resume f371a2290006d94ea10039ed1f525130454d47 saved in json file
# ********************
# Start parce 5a4cbf6800036f997c0039ed1f787258436850
# Resume 5a4cbf6800036f997c0039ed1f787258436850 saved in json file
# ********************
# Start parce 2be3d174000295abd10039ed1f336f35763868
# Resume 2be3d174000295abd10039ed1f336f35763868 saved in json file
# ********************
# Start parce 593b3d3500058853280039ed1f474155454b75
# Resume 593b3d3500058853280039ed1f474155454b75 saved in json file
# ********************
# Start parce c07583c5000368b4cf0039ed1f427347487753
# Resume c07583c5000368b4cf0039ed1f427347487753 saved in json file
# ********************
# Start parce ad672e1900044588c90039ed1f673738415561
# Resume ad672e1900044588c90039ed1f673738415561 saved in json file
# ********************
# Start parce 1d594d55000290e60a0039ed1f6a354c4c6f5a
# Resume 1d594d55000290e60a0039ed1f6a354c4c6f5a saved in json file
# ********************
# Start parce 25fde9dc0001f7afb30039ed1f35356931576b
# Resume 25fde9dc0001f7afb30039ed1f35356931576b saved in json file
# ********************
# Start parce d342dc9600070fba2f0039ed1f436741657677
# Resume d342dc9600070fba2f0039ed1f436741657677 saved in json file
# ********************
# Start parce cb2e3f9c0006dc67a90039ed1f6666337a6550
# Resume cb2e3f9c0006dc67a90039ed1f6666337a6550 saved in json file
# ********************
# Start parce 255381940001f062c00039ed1f6957614a6841
# Resume 255381940001f062c00039ed1f6957614a6841 saved in json file
# ********************
# Start parce 571ff7da0001f6d5830039ed1f4b767a373950
# Resume 571ff7da0001f6d5830039ed1f4b767a373950 saved in json file
# ********************
# Start parce da370a0e0008efa4e40039ed1f6c654c355077
# Resume da370a0e0008efa4e40039ed1f6c654c355077 saved in json file
# ********************
# Start parce f4f1f02c00085865b10039ed1f776f466d6c54
# Resume f4f1f02c00085865b10039ed1f776f466d6c54 saved in json file
# ********************
# Start parce a7b7e8280008e9cd040039ed1f3739306b6d63
# Resume a7b7e8280008e9cd040039ed1f3739306b6d63 saved in json file
# ********************
# Start parce 44c5aba20008b98cc10039ed1f70426b314756
# Resume 44c5aba20008b98cc10039ed1f70426b314756 saved in json file
# ********************
# Start parce f8e8a28b0001f29e830039ed1f323663713642
# Resume f8e8a28b0001f29e830039ed1f323663713642 saved in json file
# ********************
# Start parce 00dbccde00045555990039ed1f5a3266636452
# Resume 00dbccde00045555990039ed1f5a3266636452 saved in json file
# ********************
# Start parce a01f847f00088acf6e0039ed1f31396830586b
# Resume a01f847f00088acf6e0039ed1f31396830586b saved in json file
# ********************
# Start parce d952add5000355ead50039ed1f416e69334848
# Resume d952add5000355ead50039ed1f416e69334848 saved in json file
# ********************
# Start parce 1556baa9000934d83b0039ed1f4e6f68575962
# Resume 1556baa9000934d83b0039ed1f4e6f68575962 saved in json file
# ********************
# Start parce 6d78ef1100075b64180039ed1f52724f524239
# Resume 6d78ef1100075b64180039ed1f52724f524239 saved in json file
# ********************
# Start parce 829f8cdb0002bb96d90039ed1f797631756465
# Resume 829f8cdb0002bb96d90039ed1f797631756465 saved in json file
# ********************
# Start parce 4255a53c000320111a0039ed1f6147637a4330
# Resume 4255a53c000320111a0039ed1f6147637a4330 saved in json file
# ********************
# Start parce 6c9810110003cbc64a0039ed1f7641484e384e
# Resume 6c9810110003cbc64a0039ed1f7641484e384e saved in json file
# ********************
# Start parce 2b7bb1f200042506530039ed1f78744336484d
# Resume 2b7bb1f200042506530039ed1f78744336484d saved in json file
# ********************
# Start parce 70f839ae00024139330039ed1f497233336a4e
# Resume 70f839ae00024139330039ed1f497233336a4e saved in json file
# ********************
# Start parce d03f23380005292ab60039ed1f52774a573634
# Resume d03f23380005292ab60039ed1f52774a573634 saved in json file
# ********************
# Start parce 566e55f40002eea2830039ed1f64514b4b4336
# Resume 566e55f40002eea2830039ed1f64514b4b4336 saved in json file
# ********************
# Start parce 0d5ae10d0008e0750d0039ed1f6874636d445a
# Resume 0d5ae10d0008e0750d0039ed1f6874636d445a saved in json file
# ********************
# Start parce 768842a20004e3624e0039ed1f47655a396d59
# Resume 768842a20004e3624e0039ed1f47655a396d59 saved in json file
# ********************
# Start parce 81e80e9b000635ec0c0039ed1f543750595071
# Resume 81e80e9b000635ec0c0039ed1f543750595071 saved in json file
# ********************
# Start parce 9956576d0008866a470039ed1f684e49545162
# Resume 9956576d0008866a470039ed1f684e49545162 saved in json file
# ********************
# Start parce 5cdb7fe00008718aa80039ed1f754439664439
# Resume 5cdb7fe00008718aa80039ed1f754439664439 saved in json file
# ********************
# Start parce 8f3424e40005ca47310039ed1f583641713871
# Resume 8f3424e40005ca47310039ed1f583641713871 saved in json file
# ********************
# Start parce 7e9b84cc0001413c9c0039ed1f5a7175424778
# Resume 7e9b84cc0001413c9c0039ed1f5a7175424778 saved in json file
# ********************
# Start parce 9e1ff26a0008f1c7760039ed1f655356416749
# Resume 9e1ff26a0008f1c7760039ed1f655356416749 saved in json file
# ********************
# Start parce 679e3447000926b2f20039ed1f334f35554677
# Resume 679e3447000926b2f20039ed1f334f35554677 saved in json file
# ********************
# Start parce ca714f7c000103e94a0039ed1f745255526c6d
# Resume ca714f7c000103e94a0039ed1f745255526c6d saved in json file
# ********************
# Start parce 100f084000088f4d5b0039ed1f517170726430
# Resume 100f084000088f4d5b0039ed1f517170726430 saved in json file
# ********************
# Start parce 4096fb890004e1d24c0039ed1f57734b317a37
# Resume 4096fb890004e1d24c0039ed1f57734b317a37 saved in json file
# ********************
# Start parce a93df86c0008a9cbc60039ed1f6f304a644739
# Resume a93df86c0008a9cbc60039ed1f6f304a644739 saved in json file
# ********************
# Start parce 3f8cd9670005cf4e590039ed1f346f55733969
# Resume 3f8cd9670005cf4e590039ed1f346f55733969 saved in json file
# ********************
# Start parce aba0b5dc0004a9be7d0039ed1f5868416b4d36
# Resume aba0b5dc0004a9be7d0039ed1f5868416b4d36 saved in json file
# ********************
# Start parce 4acf0b49000844f6c80039ed1f395458353251
# Resume 4acf0b49000844f6c80039ed1f395458353251 saved in json file
# ********************
# Start parce 0d1d5f260001c67c7b0039ed1f67435a385150
# Resume 0d1d5f260001c67c7b0039ed1f67435a385150 saved in json file
# ********************
# Start parce cf18c8200008898d780039ed1f58795a77524d
# Resume cf18c8200008898d780039ed1f58795a77524d saved in json file
# ********************
# Start parce 2137d34a00014cef7d0039ed1f4a30416b7570
# Resume 2137d34a00014cef7d0039ed1f4a30416b7570 saved in json file
# ********************
# Start parce 3fbebc6d0000b185310039ed1f736563726574
# Resume 3fbebc6d0000b185310039ed1f736563726574 saved in json file
# ********************
# Start parce e24ed8d400061b0f6d0039ed1f783675735151
# Resume e24ed8d400061b0f6d0039ed1f783675735151 saved in json file
# ********************
# Start parce b2d43d18000835703d0039ed1f674d654a4338
# Resume b2d43d18000835703d0039ed1f674d654a4338 saved in json file
# ********************
# Start parce aa4f232d0008ae80730039ed1f6b536f59435a
# Resume aa4f232d0008ae80730039ed1f6b536f59435a saved in json file
# ********************
# Start parce a947a92e00037fc6190039ed1f506b4172624a
# Resume a947a92e00037fc6190039ed1f506b4172624a saved in json file
# ********************
# Start parce afc01d0c00026a22d60039ed1f4e7a34487433
# Resume afc01d0c00026a22d60039ed1f4e7a34487433 saved in json file
# ********************
# Start parce 2f11e2e50003c43f510039ed1f49374f375654
# Resume 2f11e2e50003c43f510039ed1f49374f375654 saved in json file
# ********************
# Start parce 32c50bae0005b258530039ed1f76637131744a
# Resume 32c50bae0005b258530039ed1f76637131744a saved in json file
# ********************
# Start parce c6ccc2af0003d079200039ed1f584838755850
# Resume c6ccc2af0003d079200039ed1f584838755850 saved in json file
# ********************
# Start parce 4742f7970002b694320039ed1f5a3169557778
# Resume 4742f7970002b694320039ed1f5a3169557778 saved in json file
# ********************
# Start parce c7d6ae8600080dd89e0039ed1f46386b4c3772
# Resume c7d6ae8600080dd89e0039ed1f46386b4c3772 saved in json file
# ********************
# Start parce 0189797e0003fd02ca0039ed1f68623174527a
# Resume 0189797e0003fd02ca0039ed1f68623174527a saved in json file
# ********************
# Start parce 91d450480009095a020039ed1f6d594d514759
# Resume 91d450480009095a020039ed1f6d594d514759 saved in json file
# ********************
# Start parce d441ec950008801c850039ed1f62456f485430
# Resume d441ec950008801c850039ed1f62456f485430 saved in json file
# ********************
# Start parce 55ebcbd90002d739c40039ed1f6d316a657077
# Resume 55ebcbd90002d739c40039ed1f6d316a657077 saved in json file
# ********************
# Start parce f3e1fbe10007f3d0fd0039ed1f37725a326f52
# Resume f3e1fbe10007f3d0fd0039ed1f37725a326f52 saved in json file
# ********************
# Start parce 87b6d17f00050eaff70039ed1f6b6958514858
# Resume 87b6d17f00050eaff70039ed1f6b6958514858 saved in json file
# ********************
# Start parce 8b837391000749b1d30039ed1f765238783074
# Resume 8b837391000749b1d30039ed1f765238783074 saved in json file
# ********************
# Start parce 37fefff9000271e3880039ed1f313065456571
# Resume 37fefff9000271e3880039ed1f313065456571 saved in json file
# ********************
# Start parce 8148ae2a000412c20f0039ed1f30505a664774
# Resume 8148ae2a000412c20f0039ed1f30505a664774 saved in json file
# ********************
# Start parce 682e5a10000747a3300039ed1f494c746f5137
# Resume 682e5a10000747a3300039ed1f494c746f5137 saved in json file
# ********************
# Start parce 4c4d557100083ba2550039ed1f6e6e67576a52
# Resume 4c4d557100083ba2550039ed1f6e6e67576a52 saved in json file
# ********************
# Start parce c71d0a0700009264df0039ed1f736563726574
# Resume c71d0a0700009264df0039ed1f736563726574 saved in json file
# ********************
# Start parce 315fe51a0008dcfc500039ed1f5152494f6163
# Resume 315fe51a0008dcfc500039ed1f5152494f6163 saved in json file
# ********************
# Start parce 98dfe67c0003897e9f0039ed1f6c334b6a3337
# Resume 98dfe67c0003897e9f0039ed1f6c334b6a3337 saved in json file
# ********************
# Start parce d4497aeb00042c00d30039ed1f614f6e686d39
# Resume d4497aeb00042c00d30039ed1f614f6e686d39 saved in json file
# ********************
# Start parce d1e9137e000770df3d0039ed1f546572395867
# Resume d1e9137e000770df3d0039ed1f546572395867 saved in json file
# ********************
# Start parce c3fb97fc000588a6560039ed1f43737a556873
# Resume c3fb97fc000588a6560039ed1f43737a556873 saved in json file
# ********************
# Start parce 3d84e50a00057a43b40039ed1f687a534a5748
# Resume 3d84e50a00057a43b40039ed1f687a534a5748 saved in json file
# ********************
# Start parce 359f03e300060d247f0039ed1f313445574c4e
# Resume 359f03e300060d247f0039ed1f313445574c4e saved in json file
# ********************
# Start parce 944aad7f0004de264e0039ed1f683353547133
# Resume 944aad7f0004de264e0039ed1f683353547133 saved in json file
# ********************
# Start parce 8cdc06d400022dbb450039ed1f5a646b495150
# Resume 8cdc06d400022dbb450039ed1f5a646b495150 saved in json file
# ********************
# Start parce 12117d8000041d9b120039ed1f5a4a71506f79
# Resume 12117d8000041d9b120039ed1f5a4a71506f79 saved in json file
# ********************
# Start parce 0cd8323f00076c893e0039ed1f4b366f57686c
# Resume 0cd8323f00076c893e0039ed1f4b366f57686c saved in json file
# ********************
# Start parce 61e6e5bd00074e8f140039ed1f713969544d72
# Resume 61e6e5bd00074e8f140039ed1f713969544d72 saved in json file
# ********************
# Start parce 9aa88b2c00034410980039ed1f4d6941516862
# Resume 9aa88b2c00034410980039ed1f4d6941516862 saved in json file
# ********************
# Start parce 2201f97d00026ac6670039ed1f716b6b635650
# Resume 2201f97d00026ac6670039ed1f716b6b635650 saved in json file
# ********************
# Start parce 9957756e00038ad4b40039ed1f6e3268446d4a
# Resume 9957756e00038ad4b40039ed1f6e3268446d4a saved in json file
# ********************
# Start parce a86a289f0008ba79390039ed1f377177427745
# Resume a86a289f0008ba79390039ed1f377177427745 saved in json file
# ********************
# Start parce 029b0057000195d7a90039ed1f4b4748723653
# Resume 029b0057000195d7a90039ed1f4b4748723653 saved in json file
# ********************
# Start parce c1e2d56b0000e5d69b0039ed1f6e71364e5675
# Resume c1e2d56b0000e5d69b0039ed1f6e71364e5675 saved in json file
# ********************
# Start parce 9f540fb400085c01760039ed1f71355456686a
# Resume 9f540fb400085c01760039ed1f71355456686a saved in json file
# ********************
# Start parce 465b5b63000364179f0039ed1f766b514e4659
# Resume 465b5b63000364179f0039ed1f766b514e4659 saved in json file
# ********************
# Start parce 4ad51c670002c229d90039ed1f327258467038
# Resume 4ad51c670002c229d90039ed1f327258467038 saved in json file
# ********************
# Start parce d83d8a4f000836ed880039ed1f373444444273
# Resume d83d8a4f000836ed880039ed1f373444444273 saved in json file
# ********************
# Start parce de55bcd5000218748a0039ed1f6e7732377356
# Resume de55bcd5000218748a0039ed1f6e7732377356 saved in json file
# ********************
# Start parce e2318aec0005a3fa600039ed1f694f33705332
# Resume e2318aec0005a3fa600039ed1f694f33705332 saved in json file
# ********************
# Start parce b8753ce40003cc87400039ed1f43534b493042
# Resume b8753ce40003cc87400039ed1f43534b493042 saved in json file
# ********************
# Start parce 882414bd00044c6e430039ed1f5357546a3270
# Resume 882414bd00044c6e430039ed1f5357546a3270 saved in json file
# ********************
# Start parce c4ac0a5f0004eb9cb30039ed1f7067674e4850
# Resume c4ac0a5f0004eb9cb30039ed1f7067674e4850 saved in json file
# ********************
# Start parce c264f19f00058f487b0039ed1f75316a623134
# Resume c264f19f00058f487b0039ed1f75316a623134 saved in json file
# ********************
# Start parce 0e2c65b300016f2c240039ed1f4e716f474c30
# Resume 0e2c65b300016f2c240039ed1f4e716f474c30 saved in json file
# ********************
# Start parce ad67fdf70008dc4e050039ed1f4e3356393766
# Resume ad67fdf70008dc4e050039ed1f4e3356393766 saved in json file
# ********************
# Start parce 0fc42e860004e571260039ed1f5a3139494a33
# Resume 0fc42e860004e571260039ed1f5a3139494a33 saved in json file
# ********************
# Start parce a10cf7c000076110060039ed1f566176303845
# Resume a10cf7c000076110060039ed1f566176303845 saved in json file
# ********************
# Start parce 7508f5ed00044511b20039ed1f6845366e3474
# Resume 7508f5ed00044511b20039ed1f6845366e3474 saved in json file
# ********************
# Start parce 0144cd1e00033545ef0039ed1f434233505731
# Resume 0144cd1e00033545ef0039ed1f434233505731 saved in json file
# ********************
# Start parce 898cb99d000035952f0039ed1f736563726574
# Resume 898cb99d000035952f0039ed1f736563726574 saved in json file
# ********************
# Start parce 2a359cfa00020466010039ed1f7238474b686f
# Resume 2a359cfa00020466010039ed1f7238474b686f saved in json file
# ********************
# Start parce ebff1c5d0001caf99c0039ed1f69476641536e
# Resume ebff1c5d0001caf99c0039ed1f69476641536e saved in json file
# ********************
# Start parce 8e56f6750004d11fb40039ed1f435a42767259
# Resume 8e56f6750004d11fb40039ed1f435a42767259 saved in json file
# ********************
# Start parce 2dc08099000911ce140039ed1f6f4759555750
# Resume 2dc08099000911ce140039ed1f6f4759555750 saved in json file
# ********************
# Start parce cedc26b80002c00c370039ed1f615631373062
# Resume cedc26b80002c00c370039ed1f615631373062 saved in json file
# ********************
# Start parce 5074a6100001fc10940039ed1f45677350336b
# Resume 5074a6100001fc10940039ed1f45677350336b saved in json file
# ********************
# Start parce c018dde000050286460039ed1f526a374c306c
# Resume c018dde000050286460039ed1f526a374c306c saved in json file
# ********************
# Start parce ee7b65a6000910df480039ed1f4968334d6253
# Resume ee7b65a6000910df480039ed1f4968334d6253 saved in json file
# ********************
# Start parce f8cb039500019581d80039ed1f4f384a6a6f43
# Resume f8cb039500019581d80039ed1f4f384a6a6f43 saved in json file
# ********************
# Start parce 736bdcdf00082870040039ed1f357030646c37
# Resume 736bdcdf00082870040039ed1f357030646c37 saved in json file
# ********************
# Start parce dd90b49f000190df670039ed1f6a5043665176
# Resume dd90b49f000190df670039ed1f6a5043665176 saved in json file
# ********************
# Start parce 5be566140000e4effa0039ed1f54736343394f
# Resume 5be566140000e4effa0039ed1f54736343394f saved in json file
# ********************
# Start parce b3744e8d000932ae780039ed1f47544e7a335a
# Resume b3744e8d000932ae780039ed1f47544e7a335a saved in json file
# ********************
# Start parce b97f0dc600079801340039ed1f7a6e6a4b7759
# Resume b97f0dc600079801340039ed1f7a6e6a4b7759 saved in json file
# ********************
# Start parce ce793fb30008faac9c0039ed1f754a41756b33
# Resume ce793fb30008faac9c0039ed1f754a41756b33 saved in json file
# ********************
# Start parce 4348d9330003a73ba40039ed1f56794c346151
# Resume 4348d9330003a73ba40039ed1f56794c346151 saved in json file
# ********************
# Start parce 993229b3000260b93f0039ed1f78374b726b38
# Resume 993229b3000260b93f0039ed1f78374b726b38 saved in json file
# ********************
# Start parce 3400c23000034b684e0039ed1f6c3730383765
# Resume 3400c23000034b684e0039ed1f6c3730383765 saved in json file
# ********************
# Start parce 49aec61200019d194b0039ed1f34636376524e
# Resume 49aec61200019d194b0039ed1f34636376524e saved in json file
# ********************
# Start parce 310158c20003ea5a420039ed1f7631376d4436
# Resume 310158c20003ea5a420039ed1f7631376d4436 saved in json file
# ********************
# Start parce 151dc9a900091f188f0039ed1f6e5746336d31
# Resume 151dc9a900091f188f0039ed1f6e5746336d31 saved in json file
# ********************
# Start parce 8e66b1780001f5851d0039ed1f757a4b457446
# Resume 8e66b1780001f5851d0039ed1f757a4b457446 saved in json file
# ********************
# Start parce 7d5b412e0000689c120039ed1f736563726574
# Resume 7d5b412e0000689c120039ed1f736563726574 saved in json file
# ********************
# Start parce 6e0a2e720002714edf0039ed1f6a5970425448
# Resume 6e0a2e720002714edf0039ed1f6a5970425448 saved in json file
# ********************
# Start parce 42bac2e40008a6de010039ed1f773248506f41
# Resume 42bac2e40008a6de010039ed1f773248506f41 saved in json file
# ********************
# Start parce 42162f6c0008e7f1460039ed1f647061687a46
# Resume 42162f6c0008e7f1460039ed1f647061687a46 saved in json file
# ********************
# Start parce e08fee380007e5cc0e0039ed1f775752546f5a
# Resume e08fee380007e5cc0e0039ed1f775752546f5a saved in json file
# ********************
# Start parce 42e6117f0007dc018e0039ed1f5266706b3947
# Resume 42e6117f0007dc018e0039ed1f5266706b3947 saved in json file
# ********************
# Start parce 8a5367de00084b42e20039ed1f735943467177
# Resume 8a5367de00084b42e20039ed1f735943467177 saved in json file
# ********************
# Start parce 44f2bb3b0005d96e4a0039ed1f385137707449
# Resume 44f2bb3b0005d96e4a0039ed1f385137707449 saved in json file
# ********************
# Start parce d1fdb2670003ad832d0039ed1f4d6a50786370
# Resume d1fdb2670003ad832d0039ed1f4d6a50786370 saved in json file
# ********************
# Start parce 0733dcbd0001e103e50039ed1f496c315a5678
# Resume 0733dcbd0001e103e50039ed1f496c315a5678 saved in json file
# ********************
# Start parce e971575100018f990f0039ed1f326264515143
# Resume e971575100018f990f0039ed1f326264515143 saved in json file
# ********************
# Start parce dc86845c0002714b280039ed1f4b716c454c75
# Resume dc86845c0002714b280039ed1f4b716c454c75 saved in json file
# ********************
# Start parce 3042d4dc0003a1697a0039ed1f446636766e51
# Resume 3042d4dc0003a1697a0039ed1f446636766e51 saved in json file
# ********************
# Start parce 3d2f174d0008118cda0039ed1f4263566b3661
# Resume 3d2f174d0008118cda0039ed1f4263566b3661 saved in json file
# ********************
# Start parce d6465ce2000742fb910039ed1f463153566f52
# Resume d6465ce2000742fb910039ed1f463153566f52 saved in json file
# ********************
# Start parce 6e6dba6e00089109f80039ed1f7069754e7173
# Resume 6e6dba6e00089109f80039ed1f7069754e7173 saved in json file
# ********************
# Start parce e0ce43b70007d5e9fc0039ed1f377056766579
# Resume e0ce43b70007d5e9fc0039ed1f377056766579 saved in json file
# ********************
# Start parce b8398043000256186d0039ed1f4e4b6a757249
# Resume b8398043000256186d0039ed1f4e4b6a757249 saved in json file
# ********************
# Start parce 2c2a5dd40003c3a92d0039ed1f71426a56726e
# Resume 2c2a5dd40003c3a92d0039ed1f71426a56726e saved in json file
# ********************
# Start parce dc21d63f0003e0507a0039ed1f584c55325641
# Resume dc21d63f0003e0507a0039ed1f584c55325641 saved in json file
# ********************
# Start parce cc36ec4c0007d3fd910039ed1f547659487335
# Resume cc36ec4c0007d3fd910039ed1f547659487335 saved in json file
# ********************
# Start parce e3f89366000647c9c90039ed1f365862436c67
# Resume e3f89366000647c9c90039ed1f365862436c67 saved in json file
# ********************
# Start parce df052ffe00044534790039ed1f485a3963626e
# Resume df052ffe00044534790039ed1f485a3963626e saved in json file
# ********************
# Start parce 1c6d952400088d740e0039ed1f6d673279666e
# Resume 1c6d952400088d740e0039ed1f6d673279666e saved in json file
# ********************
# Start parce 8b1cdd1600020634eb0039ed1f644c78487471
# Resume 8b1cdd1600020634eb0039ed1f644c78487471 saved in json file
# ********************
# Start parce fe555098000473281d0039ed1f785a54494935
# Resume fe555098000473281d0039ed1f785a54494935 saved in json file
# ********************
# Start parce c9f37d4f00009179aa0039ed1f736563726574
# Resume c9f37d4f00009179aa0039ed1f736563726574 saved in json file
# ********************
# Start parce fd2c835000028249030039ed1f3178466c6442
# Resume fd2c835000028249030039ed1f3178466c6442 saved in json file
# ********************
# Start parce 11da16b700083ab9b10039ed1f50634d366a57
# Resume 11da16b700083ab9b10039ed1f50634d366a57 saved in json file
# ********************
# Start parce 67d998b30002a6aba20039ed1f654d65717a6a
# Resume 67d998b30002a6aba20039ed1f654d65717a6a saved in json file
# ********************
# Start parce bec9f3ae00023708ee0039ed1f637461586954
# Resume bec9f3ae00023708ee0039ed1f637461586954 saved in json file
# ********************
# Start parce b462f93500036339700039ed1f4231786a6e6d
# Resume b462f93500036339700039ed1f4231786a6e6d saved in json file
# ********************
# Start parce 4e1aef8f0008b5dbc70039ed1f653245375646
# Resume 4e1aef8f0008b5dbc70039ed1f653245375646 saved in json file
# ********************
# Start parce d29c55570001e18a3b0039ed1f7a4a42726351
# Resume d29c55570001e18a3b0039ed1f7a4a42726351 saved in json file
# ********************
# Start parce 9cfb669f00071914130039ed1f426b6c45565a
# Resume 9cfb669f00071914130039ed1f426b6c45565a saved in json file
# ********************
# Start parce 2d5be6b7000821bf180039ed1f505178557064
# Resume 2d5be6b7000821bf180039ed1f505178557064 saved in json file
# ********************
# Start parce 58a6338500034fa2960039ed1f66474f474f33
# Resume 58a6338500034fa2960039ed1f66474f474f33 saved in json file
# ********************
# Start parce 2d890654000311beb10039ed1f7a3449425141
# Resume 2d890654000311beb10039ed1f7a3449425141 saved in json file
# ********************
# Start parce 51cff5ba0004006c240039ed1f545550695a35
# Resume 51cff5ba0004006c240039ed1f545550695a35 saved in json file
# ********************
# Start parce 6bb6866300061255320039ed1f34444f4b3236
# Resume 6bb6866300061255320039ed1f34444f4b3236 saved in json file
# ********************
# Start parce 8ef2ac3800016eea1f0039ed1f396963697344
# Resume 8ef2ac3800016eea1f0039ed1f396963697344 saved in json file
# ********************
# Start parce 719043fb0008560b5a0039ed1f6e3265734958
# Resume 719043fb0008560b5a0039ed1f6e3265734958 saved in json file
# ********************
# Start parce 5175c2770000dafa360039ed1f7a75486a4852
# Resume 5175c2770000dafa360039ed1f7a75486a4852 saved in json file
# ********************
# Start parce 511d6b890001eee3d20039ed1f754269573542
# Resume 511d6b890001eee3d20039ed1f754269573542 saved in json file
# ********************
# Start parce 82a3ecb200006ae9040039ed1f736563726574
# Resume 82a3ecb200006ae9040039ed1f736563726574 saved in json file
# ********************
# Start parce 1a98fa0300070f59d10039ed1f396c4a63316c
# Resume 1a98fa0300070f59d10039ed1f396c4a63316c saved in json file
# ********************
# Start parce 9ced1587000884cb4d0039ed1f5149476d4e70
# Resume 9ced1587000884cb4d0039ed1f5149476d4e70 saved in json file
# ********************
# Start parce bdc9afd50008118a540039ed1f776153644d41
# Resume bdc9afd50008118a540039ed1f776153644d41 saved in json file
# ********************
# Start parce cd5584610001ad5ba50039ed1f623575766d75
# Resume cd5584610001ad5ba50039ed1f623575766d75 saved in json file
# ********************
# Start parce 12f2d51c0008ae06340039ed1f6b32376c7a37
# Resume 12f2d51c0008ae06340039ed1f6b32376c7a37 saved in json file
# ********************
# Start parce 96c141dd00075c86040039ed1f6a7950393952
# Resume 96c141dd00075c86040039ed1f6a7950393952 saved in json file
# ********************
# Start parce 940763fe00038a4f1f0039ed1f57504e343369
# Resume 940763fe00038a4f1f0039ed1f57504e343369 saved in json file
# ********************
# Start parce a41ea1ce0005580dc60039ed1f7733436c3536
# Resume a41ea1ce0005580dc60039ed1f7733436c3536 saved in json file
# ********************
# Start parce 4de8618e0001ce10c30039ed1f437068463649
# Resume 4de8618e0001ce10c30039ed1f437068463649 saved in json file
# ********************
# Start parce f0b53c50000741e02f0039ed1f6942634b5333
# Resume f0b53c50000741e02f0039ed1f6942634b5333 saved in json file
# ********************
# Start parce 0858b5b700040208db0039ed1f4e4357666d4f
# Resume 0858b5b700040208db0039ed1f4e4357666d4f saved in json file
# ********************
# Start parce f44959e600051847180039ed1f36434d32796b
# Resume f44959e600051847180039ed1f36434d32796b saved in json file
# ********************
# Start parce 595fe9de00073f4ddc0039ed1f6c39414c506a
# Resume 595fe9de00073f4ddc0039ed1f6c39414c506a saved in json file
# ********************
# Start parce 833017d900022cc8be0039ed1f6b4d6f585262
# Resume 833017d900022cc8be0039ed1f6b4d6f585262 saved in json file
# ********************
# Start parce b1f15f6b0007e8c2ef0039ed1f663764787741
# Resume b1f15f6b0007e8c2ef0039ed1f663764787741 saved in json file
# ********************
# Start parce 44ed1ee300088931e00039ed1f747a306e4e64
# Resume 44ed1ee300088931e00039ed1f747a306e4e64 saved in json file
# ********************
# Start parce e3fe8b0c0008f0cfac0039ed1f694e6756614b
# Resume e3fe8b0c0008f0cfac0039ed1f694e6756614b saved in json file
# ********************
# Start parce dd9ab17200032b5b5f0039ed1f476d73486a39
# Resume dd9ab17200032b5b5f0039ed1f476d73486a39 saved in json file
# ********************
# Start parce 1863b95900027a15770039ed1f736d6d7a424f
# Resume 1863b95900027a15770039ed1f736d6d7a424f saved in json file
# ********************
# Start parce 2a9756cf0006ee85de0039ed1f756a63626174
# Resume 2a9756cf0006ee85de0039ed1f756a63626174 saved in json file
# ********************
# Start parce 871c9c690002da8b450039ed1f503171424168
# Resume 871c9c690002da8b450039ed1f503171424168 saved in json file
# ********************
# Start parce e0c924d00007abd2f50039ed1f556778645a4d
# Resume e0c924d00007abd2f50039ed1f556778645a4d saved in json file
# ********************
# Start parce 3e9359e600008cc6d90039ed1f736563726574
# Resume 3e9359e600008cc6d90039ed1f736563726574 saved in json file
# ********************
# Start parce fc940d560001ffe1c40039ed1f503741667a53
# Resume fc940d560001ffe1c40039ed1f503741667a53 saved in json file
# ********************
# Start parce ecbb8c1f00069987990039ed1f785a45436d73
# Resume ecbb8c1f00069987990039ed1f785a45436d73 saved in json file
# ********************
# Start parce 90b0a52c00025f21250039ed1f613474463664
# Resume 90b0a52c00025f21250039ed1f613474463664 saved in json file
# ********************
# Start parce 61071bfc00074ccbc90039ed1f39536c736a78
# Resume 61071bfc00074ccbc90039ed1f39536c736a78 saved in json file
# ********************
# Start parce 24817f140008dc49900039ed1f694441624e37
# Resume 24817f140008dc49900039ed1f694441624e37 saved in json file
# ********************
# Start parce eaee0b9900041cb7480039ed1f416c68547643
# Resume eaee0b9900041cb7480039ed1f416c68547643 saved in json file
# ********************
# Start parce 3f818d450002931cb80039ed1f564e4c494b6c
# Resume 3f818d450002931cb80039ed1f564e4c494b6c saved in json file
# ********************
# Start parce ada74c700002e1e37c0039ed1f584251554842
# Resume ada74c700002e1e37c0039ed1f584251554842 saved in json file
# ********************
# Start parce 0a9744200005a34f5f0039ed1f6134574d5578
# Resume 0a9744200005a34f5f0039ed1f6134574d5578 saved in json file
# ********************
# Start parce fc901c6500015051bb0039ed1f59566e493337
# Resume fc901c6500015051bb0039ed1f59566e493337 saved in json file
# ********************
# Start parce aadcceb800024879580039ed1f4f304a537558
# Resume aadcceb800024879580039ed1f4f304a537558 saved in json file
# ********************
# Start parce 40f8b366000215ead00039ed1f635846753846
# Resume 40f8b366000215ead00039ed1f635846753846 saved in json file
# ********************
# Start parce 5819e7500008c364d50039ed1f664758454f4e
# Resume 5819e7500008c364d50039ed1f664758454f4e saved in json file
# ********************
# Start parce 63d8d65000066dd5b40039ed1f4b39686a4335
# Resume 63d8d65000066dd5b40039ed1f4b39686a4335 saved in json file
# ********************
# Start parce 2459f60a0003d65d390039ed1f317339364135
# Resume 2459f60a0003d65d390039ed1f317339364135 saved in json file
# ********************
# Start parce 604e57aa0001afab5c0039ed1f394879484738
# Resume 604e57aa0001afab5c0039ed1f394879484738 saved in json file
# ********************
# Start parce ffbcf023000392a0c90039ed1f6d687373634c
# Resume ffbcf023000392a0c90039ed1f6d687373634c saved in json file
# ********************
# Start parce df8a375200031160990039ed1f57344d504d5a
# Resume df8a375200031160990039ed1f57344d504d5a saved in json file
# ********************
# Start parce a5da5ee900006f128e0039ed1f736563726574
# Resume a5da5ee900006f128e0039ed1f736563726574 saved in json file
# ********************
# Start parce 8ebc5e1000009d88f80039ed1f736563726574
# Resume 8ebc5e1000009d88f80039ed1f736563726574 saved in json file
# ********************
# Start parce 41ed020f00052d1a290039ed1f55526d67546b
# Resume 41ed020f00052d1a290039ed1f55526d67546b saved in json file
# ********************
# Start parce 6ded6a73000833f82f0039ed1f527350576164
# Resume 6ded6a73000833f82f0039ed1f527350576164 saved in json file
# ********************
# Start parce 431c5ab400031f3c660039ed1f4d6451755858
# Resume 431c5ab400031f3c660039ed1f4d6451755858 saved in json file
# ********************
# Start parce 16fe5c730005b329fe0039ed1f376655556275
# Resume 16fe5c730005b329fe0039ed1f376655556275 saved in json file
# ********************
# Start parce 88a11f8b0008e1fcb10039ed1f716a35686577
# Resume 88a11f8b0008e1fcb10039ed1f716a35686577 saved in json file
# ********************
# Start parce 68e1c50500081299da0039ed1f747266423548
# Resume 68e1c50500081299da0039ed1f747266423548 saved in json file
# ********************
# Start parce 213c139f0007ce90ba0039ed1f49677057476d
# Resume 213c139f0007ce90ba0039ed1f49677057476d saved in json file
# ********************
# Start parce 3e085c5e0000c8d6240039ed1f69555171354c
# Resume 3e085c5e0000c8d6240039ed1f69555171354c saved in json file
# ********************
# Start parce 3edd43100003f693350039ed1f68566b554935
# Resume 3edd43100003f693350039ed1f68566b554935 saved in json file
# ********************
# Start parce 4a3eb7bc0003c74bcf0039ed1f696f78386449
# Resume 4a3eb7bc0003c74bcf0039ed1f696f78386449 saved in json file
# ********************
# Start parce 417183020004e988930039ed1f69715354464a
# Resume 417183020004e988930039ed1f69715354464a saved in json file
# ********************
# Start parce 452302f600087ef8130039ed1f445939744441
# Resume 452302f600087ef8130039ed1f445939744441 saved in json file
# ********************
# Start parce c4584a2e000263380d0039ed1f514c37584c53
# Resume c4584a2e000263380d0039ed1f514c37584c53 saved in json file
# ********************
# Start parce e87c5b7200030ec0420039ed1f785545505a53
# Resume e87c5b7200030ec0420039ed1f785545505a53 saved in json file
# ********************
# Start parce e7a892fd000252a99a0039ed1f66364c376739
# Resume e7a892fd000252a99a0039ed1f66364c376739 saved in json file
# ********************
# Start parce 3a177971000882ac290039ed1f754445716e77
# Resume 3a177971000882ac290039ed1f754445716e77 saved in json file
# ********************
# Start parce aa1ac9350008b3ce6b0039ed1f746a77506233
# Resume aa1ac9350008b3ce6b0039ed1f746a77506233 saved in json file
# ********************
# Start parce d15e992d0002371d310039ed1f377137364b41
# Resume d15e992d0002371d310039ed1f377137364b41 saved in json file
# ********************
# Start parce 986fd2460001d1fbe80039ed1f4a4e7433434f
# Resume 986fd2460001d1fbe80039ed1f4a4e7433434f saved in json file
# ********************
# Start parce 435210870001912b950039ed1f69694f636176
# Resume 435210870001912b950039ed1f69694f636176 saved in json file
# ********************
# Start parce ecad8109000247a2f00039ed1f793146696e59
# Resume ecad8109000247a2f00039ed1f793146696e59 saved in json file
# ********************
# Start parce ff3232d20006ebe48a0039ed1f66514e7a7341
# Resume ff3232d20006ebe48a0039ed1f66514e7a7341 saved in json file
# ********************
# Start parce 95e4b9a20003a00ecb0039ed1f3751576c3649
# Resume 95e4b9a20003a00ecb0039ed1f3751576c3649 saved in json file
# ********************
# Start parce e6cb693e00081908010039ed1f41594b556172
# Resume e6cb693e00081908010039ed1f41594b556172 saved in json file
# ********************
# Start parce 146197990002034fb60039ed1f776f49734a49
# Resume 146197990002034fb60039ed1f776f49734a49 saved in json file
# ********************
# Start parce 0a45d0610005262f930039ed1f6866326a5454
# Resume 0a45d0610005262f930039ed1f6866326a5454 saved in json file
# ********************
# Start parce 889150150003ccef460039ed1f5a3363634d73
# Resume 889150150003ccef460039ed1f5a3363634d73 saved in json file
# ********************
# Start parce 36acf189000602225e0039ed1f4b636a585839
# Resume 36acf189000602225e0039ed1f4b636a585839 saved in json file
# ********************
# Start parce f5bc19b5000219ab9b0039ed1f725271575663
# Resume f5bc19b5000219ab9b0039ed1f725271575663 saved in json file
# ********************
# Start parce 12093ccc0001a612bb0039ed1f7032484f7069
# Resume 12093ccc0001a612bb0039ed1f7032484f7069 saved in json file
# ********************
# Start parce 8ea78e660008d04f9a0039ed1f72717569717a
# Resume 8ea78e660008d04f9a0039ed1f72717569717a saved in json file
# ********************
# Start parce bdce6b4b0007e92fd40039ed1f6546764f5647
# Resume bdce6b4b0007e92fd40039ed1f6546764f5647 saved in json file
# ********************
# Start parce 57b9ee6600087549c70039ed1f3737424d6445
# Resume 57b9ee6600087549c70039ed1f3737424d6445 saved in json file
# ********************
# Start parce 402f51d40007e022640039ed1f366a4c4e5066
# Resume 402f51d40007e022640039ed1f366a4c4e5066 saved in json file
# ********************
# Start parce 83fad8860008d278810039ed1f39595576356b
# Resume 83fad8860008d278810039ed1f39595576356b saved in json file
# ********************
# Start parce 3a586b5d00083a82d00039ed1f5a6a636d4150
# Resume 3a586b5d00083a82d00039ed1f5a6a636d4150 saved in json file
# ********************
# Start parce 5d807b7a00041dee500039ed1f6b75335a4263
# Resume 5d807b7a00041dee500039ed1f6b75335a4263 saved in json file
# ********************
# Start parce 684e46b40007eadff90039ed1f503872663662
# Resume 684e46b40007eadff90039ed1f503872663662 saved in json file
# ********************
# Start parce b0ebc70200021e7cbb0039ed1f706353785042
# Resume b0ebc70200021e7cbb0039ed1f706353785042 saved in json file
# ********************
# Start parce ea5db04a0007f887ff0039ed1f764e4b6a3867
# Resume ea5db04a0007f887ff0039ed1f764e4b6a3867 saved in json file
# ********************
# Start parce 066f1bad0008022d4c0039ed1f4d72434e3868
# Resume 066f1bad0008022d4c0039ed1f4d72434e3868 saved in json file
# ********************
# Start parce 911e1cb6000298a7f10039ed1f76476a554866
# Resume 911e1cb6000298a7f10039ed1f76476a554866 saved in json file
# ********************
# Start parce 7599fb1900035d6a430039ed1f417361676777
# Resume 7599fb1900035d6a430039ed1f417361676777 saved in json file
# ********************
# Start parce d567ac450003ad555d0039ed1f37517a584974
# Resume d567ac450003ad555d0039ed1f37517a584974 saved in json file
# ********************
# Start parce 301a97c20009064fcc0039ed1f39676a69734f
# Resume 301a97c20009064fcc0039ed1f39676a69734f saved in json file
# ********************
# Start parce 410100360008aa620a0039ed1f794976455372
# Resume 410100360008aa620a0039ed1f794976455372 saved in json file
# ********************
# Start parce 164f1c69000519e6b40039ed1f566969794477
# Resume 164f1c69000519e6b40039ed1f566969794477 saved in json file
# ********************
# Start parce 732b5dd400039a71f80039ed1f59534a7a5270
# Resume 732b5dd400039a71f80039ed1f59534a7a5270 saved in json file
# ********************
# Start parce 0cf6ea94000579e9420039ed1f7a6c65425376
# Resume 0cf6ea94000579e9420039ed1f7a6c65425376 saved in json file
# ********************
# Start parce b07dec3c00076ca1ee0039ed1f4d367a796970
# Resume b07dec3c00076ca1ee0039ed1f4d367a796970 saved in json file
# ********************
# Start parce 1e89238800092156a10039ed1f314a59664746
# Resume 1e89238800092156a10039ed1f314a59664746 saved in json file
# ********************
# Start parce ce9884d90004630dc70039ed1f65316c4d564a
# Resume ce9884d90004630dc70039ed1f65316c4d564a saved in json file
# ********************
# Start parce c9dc4f650007dc648d0039ed1f6a504139487a
# Resume c9dc4f650007dc648d0039ed1f6a504139487a saved in json file
# ********************
# Start parce cb54fcc100059a258c0039ed1f386779354772
# Resume cb54fcc100059a258c0039ed1f386779354772 saved in json file
# ********************
# Start parce 2216de200004bfcec60039ed1f4f6257326d38
# Resume 2216de200004bfcec60039ed1f4f6257326d38 saved in json file
# ********************
# Start parce 3036305e00060179f90039ed1f41577352546c
# Resume 3036305e00060179f90039ed1f41577352546c saved in json file
# ********************
# Start parce cdc0c9360002cdd0a10039ed1f344f75563534
# Resume cdc0c9360002cdd0a10039ed1f344f75563534 saved in json file
# ********************
# Start parce 17fbe9dd0002376a820039ed1f786a5a524c79
# Resume 17fbe9dd0002376a820039ed1f786a5a524c79 saved in json file
# ********************
# Start parce 5ed06a5900085891700039ed1f314f31477249
# Resume 5ed06a5900085891700039ed1f314f31477249 saved in json file
# ********************
# Start parce 06a309d300041c99be0039ed1f45485168354f
# Resume 06a309d300041c99be0039ed1f45485168354f saved in json file
# ********************
# Start parce 9b0d68e00007253dc80039ed1f723478684150
# Resume 9b0d68e00007253dc80039ed1f723478684150 saved in json file
# ********************
# Start parce cca6b00100088513ba0039ed1f466633353273
# Resume cca6b00100088513ba0039ed1f466633353273 saved in json file
# ********************
# Start parce 237d1c360008b8e8b20039ed1f315979306b53
# Resume 237d1c360008b8e8b20039ed1f315979306b53 saved in json file
# ********************
# Start parce d5e952d200076570620039ed1f7744616c6d76
# Resume d5e952d200076570620039ed1f7744616c6d76 saved in json file
# ********************
# Start parce 2e7cf4bb00080c60130039ed1f416963584d30
# Resume 2e7cf4bb00080c60130039ed1f416963584d30 saved in json file
# ********************
# Start parce d93fd1eb0001f31e500039ed1f757636547954
# Resume d93fd1eb0001f31e500039ed1f757636547954 saved in json file
# ********************
# Start parce efff6d510008c298d60039ed1f4f5152364343
# Resume efff6d510008c298d60039ed1f4f5152364343 saved in json file
# ********************
# Start parce 68ecc37f000252395b0039ed1f7247304f5333
# Resume 68ecc37f000252395b0039ed1f7247304f5333 saved in json file
# ********************
# Start parce 2484acfc000888fb620039ed1f655930534147
# Resume 2484acfc000888fb620039ed1f655930534147 saved in json file
# ********************
# Start parce f906fea0000765931d0039ed1f6465454c4565
# Resume f906fea0000765931d0039ed1f6465454c4565 saved in json file
# ********************
# Start parce 33b33915000773ebf30039ed1f7a72626c7537
# Resume 33b33915000773ebf30039ed1f7a72626c7537 saved in json file
# ********************
# Start parce 8668d0750005347d830039ed1f387570454c69
# Resume 8668d0750005347d830039ed1f387570454c69 saved in json file
# ********************
# Start parce f33e4b520001a577ad0039ed1f684a44644d63
# Resume f33e4b520001a577ad0039ed1f684a44644d63 saved in json file
# ********************
# Start parce 9b25213a000592f1de0039ed1f6a6469715943
# Resume 9b25213a000592f1de0039ed1f6a6469715943 saved in json file
# ********************
# Start parce d99465ab0007f4276c0039ed1f384e76375a36
# Resume d99465ab0007f4276c0039ed1f384e76375a36 saved in json file
# ********************
# Start parce 7df15b200009049a750039ed1f623537526a37
# Resume 7df15b200009049a750039ed1f623537526a37 saved in json file
# ********************
# Start parce 7fdb3f6100082badab0039ed1f6871506e6850
# Resume 7fdb3f6100082badab0039ed1f6871506e6850 saved in json file
# ********************
# Start parce 43bba735000761ce5b0039ed1f695973533961
# Resume 43bba735000761ce5b0039ed1f695973533961 saved in json file
# ********************
# Start parce b36e0d350008e780fe0039ed1f6f417479344b
# Resume b36e0d350008e780fe0039ed1f6f417479344b saved in json file
# ********************
# Start parce 400c79320005c2abb90039ed1f364b4e4c686f
# Resume 400c79320005c2abb90039ed1f364b4e4c686f saved in json file
# ********************
# Start parce 4b8747ac0007c69e1c0039ed1f374d78796c6a
# Resume 4b8747ac0007c69e1c0039ed1f374d78796c6a saved in json file
# ********************
# Start parce 55c98247000763dba10039ed1f6b56664a4e79
# Resume 55c98247000763dba10039ed1f6b56664a4e79 saved in json file
# ********************
# Start parce bd338684000909154e0039ed1f6a6478304544
# Resume bd338684000909154e0039ed1f6a6478304544 saved in json file
# ********************
# Start parce f6d1105200066c8f250039ed1f4f7267417238
# Resume f6d1105200066c8f250039ed1f4f7267417238 saved in json file
# ********************
# Start parce b7dd39d20007f3a7f70039ed1f307546514c39
# Resume b7dd39d20007f3a7f70039ed1f307546514c39 saved in json file
# ********************
# Start parce 11aa21fd00079632c50039ed1f457268724964
# Resume 11aa21fd00079632c50039ed1f457268724964 saved in json file
# ********************
# Start parce f83defcd000551d4d90039ed1f7868546b7559
# Resume f83defcd000551d4d90039ed1f7868546b7559 saved in json file
# ********************
# Start parce b3c19d90000198331e0039ed1f53303752364c
# Resume b3c19d90000198331e0039ed1f53303752364c saved in json file
# ********************
# Start parce 252fef8b0005364ca00039ed1f7a6c4d593445
# Resume 252fef8b0005364ca00039ed1f7a6c4d593445 saved in json file
# ********************
# Start parce 18d3ab0e000612e0120039ed1f7477624a5476
# Resume 18d3ab0e000612e0120039ed1f7477624a5476 saved in json file
# ********************
# Start parce 63056d590002b6f1240039ed1f45464c726276
# Resume 63056d590002b6f1240039ed1f45464c726276 saved in json file
# ********************
# Start parce a60562b600087228860039ed1f5a726d517867
# Resume a60562b600087228860039ed1f5a726d517867 saved in json file
# ********************
# Start parce 3812016a00085b7f3c0039ed1f4d55574a695a
# Resume 3812016a00085b7f3c0039ed1f4d55574a695a saved in json file
# ********************
# Start parce f21c59470004152c750039ed1f786f32494c50
# Resume f21c59470004152c750039ed1f786f32494c50 saved in json file
# ********************
# Start parce ab04ce120002e04d3d0039ed1f756676357871
# Resume ab04ce120002e04d3d0039ed1f756676357871 saved in json file
# ********************
# Start parce 8a9ab7480004664a0c0039ed1f6a454b726547
# Resume 8a9ab7480004664a0c0039ed1f6a454b726547 saved in json file
# ********************
# Start parce 92301e41000918a3f60039ed1f704c65595865
# Resume 92301e41000918a3f60039ed1f704c65595865 saved in json file
# ********************
# Start parce 02b65df00009235e3c0039ed1f45353169576a
# Resume 02b65df00009235e3c0039ed1f45353169576a saved in json file
# ********************
# Start parce bab5c4940006c030940039ed1f324a306e6d65
# Resume bab5c4940006c030940039ed1f324a306e6d65 saved in json file
# ********************
# ...
# Resume 3e0875f800073a35d60039ed1f6d6532454b4f saved in json file
# ********************
# Start parce 0a94f008000336bd7c0039ed1f66717359354f
# Resume 0a94f008000336bd7c0039ed1f66717359354f saved in json file
# ********************
# Start parce 0c8548000008b808590039ed1f6d3761456844
# Resume 0c8548000008b808590039ed1f6d3761456844 saved in json file
# ********************
# Start parce 3030c7d2000075489c0039ed1f736563726574
# Resume 3030c7d2000075489c0039ed1f736563726574 saved in json file
# ********************
# Start parce 6f3634fe00090b28d00039ed1f46707378707a
# Resume 6f3634fe00090b28d00039ed1f46707378707a saved in json file
# ********************
# Start parce 00911ffa0008e38fd40039ed1f547a59725a6e
# Resume 00911ffa0008e38fd40039ed1f547a59725a6e saved in json file
# ********************
# Start parce fb2321280001ae0cda0039ed1f646130536878
# Resume fb2321280001ae0cda0039ed1f646130536878 saved in json file
# ********************
# Start parce d78afe9f0001a625ee0039ed1f37334e634e64
# Resume d78afe9f0001a625ee0039ed1f37334e634e64 saved in json file
# ********************
# Start parce 3e8666c000055b58040039ed1f70753972514f
# Resume 3e8666c000055b58040039ed1f70753972514f saved in json file
# ********************
# Start parce c0e48b5a0008fbf24e0039ed1f396d79794f70
# Resume c0e48b5a0008fbf24e0039ed1f396d79794f70 saved in json file
# ********************
# Start parce a9de0a4000036344930039ed1f693955336c51
# Resume a9de0a4000036344930039ed1f693955336c51 saved in json file
# ********************
# Start parce 5e6d421e0008a682660039ed1f473169673632
# Resume 5e6d421e0008a682660039ed1f473169673632 saved in json file
# ********************
# Start parce 37aa6a31000817fa290039ed1f7a753457704a
# Resume 37aa6a31000817fa290039ed1f7a753457704a saved in json file
# ********************
# Start parce 19b98c430008d2d8510039ed1f6673334e7930
# Resume 19b98c430008d2d8510039ed1f6673334e7930 saved in json file
# ********************
# Start parce 25f160f700013178570039ed1f5646414d4e6f
# Resume 25f160f700013178570039ed1f5646414d4e6f saved in json file
# ********************
# Start parce 691f366e0002c39dac0039ed1f336d65696851
# Resume 691f366e0002c39dac0039ed1f336d65696851 saved in json file
# ********************
# Start parce 6b3302f00008e498de0039ed1f4e4343396974
# Resume 6b3302f00008e498de0039ed1f4e4343396974 saved in json file
# ********************
# Start parce ea33b690000649483f0039ed1f476f72687a6e
# Resume ea33b690000649483f0039ed1f476f72687a6e saved in json file
# ********************
# Start parce 0e6becc00008ddd9090039ed1f4264504d4a6b
# Resume 0e6becc00008ddd9090039ed1f4264504d4a6b saved in json file
# ********************
# Start parce 87569880000575825b0039ed1f73314d437372
# Resume 87569880000575825b0039ed1f73314d437372 saved in json file
# ********************
# Start parce dea360130008d3c3f10039ed1f6d48666f6a58
# Resume dea360130008d3c3f10039ed1f6d48666f6a58 saved in json file
# ********************
# Start parce bdeda2dc00082f9e6b0039ed1f444a354c7035
# Resume bdeda2dc00082f9e6b0039ed1f444a354c7035 saved in json file
# ********************
# Start parce 592fea160008d7925a0039ed1f72477a6b4444
# Resume 592fea160008d7925a0039ed1f72477a6b4444 saved in json file
# ********************
# Start parce d847f16f00055d138d0039ed1f45774d39645a
# Resume d847f16f00055d138d0039ed1f45774d39645a saved in json file
# ********************
# Start parce 0a542c0b0000540eef0039ed1f736563726574
# Resume 0a542c0b0000540eef0039ed1f736563726574 saved in json file
# ********************
# Start parce 3cc3b9410008f4df690039ed1f684456396a47
# Resume 3cc3b9410008f4df690039ed1f684456396a47 saved in json file
# ********************
# Start parce ea8aaaf30002d4c6460039ed1f72666a704a6e
# Resume ea8aaaf30002d4c6460039ed1f72666a704a6e saved in json file
# ********************
# Start parce 9bbbc62a0008bbbdef0039ed1f6e6954744276
# Resume 9bbbc62a0008bbbdef0039ed1f6e6954744276 saved in json file
# ********************
# Start parce 0788cc4000039124ae0039ed1f517533507131
# Resume 0788cc4000039124ae0039ed1f517533507131 saved in json file
# ********************
# Start parce 3a5c22850009188db60039ed1f613563757448
# Resume 3a5c22850009188db60039ed1f613563757448 saved in json file
# ********************
# Start parce 4e118fc00002afbf330039ed1f497745754375
# Resume 4e118fc00002afbf330039ed1f497745754375 saved in json file
# ********************
# Start parce 62891cf40002dbdbd10039ed1f636a67527039
# Resume 62891cf40002dbdbd10039ed1f636a67527039 saved in json file
# ********************
# Start parce 5c70470f0008951ff40039ed1f393550643341
# Resume 5c70470f0008951ff40039ed1f393550643341 saved in json file
# ********************
# Start parce ad6851f70002b329e60039ed1f795864305a67
# Resume ad6851f70002b329e60039ed1f795864305a67 saved in json file
# ********************
# Start parce 1543decd000438d2c60039ed1f447747467072
# Resume 1543decd000438d2c60039ed1f447747467072 saved in json file
# ********************
# Start parce b8ed3e3f000837c1450039ed1f6e766b386d53
# Resume b8ed3e3f000837c1450039ed1f6e766b386d53 saved in json file
# ********************
# Start parce d2828b2b0004346a080039ed1f654765483752
# Resume d2828b2b0004346a080039ed1f654765483752 saved in json file
# ********************
# Start parce a9710d2f00071d2b070039ed1f4863596c535a
# Resume a9710d2f00071d2b070039ed1f4863596c535a saved in json file
# ********************
# Start parce a5c139a60005a5d37f0039ed1f354a786c326a
# Resume a5c139a60005a5d37f0039ed1f354a786c326a saved in json file
# ********************
# Start parce d52d3b8d00082e3d0a0039ed1f626162567638
# Resume d52d3b8d00082e3d0a0039ed1f626162567638 saved in json file
# ********************
# Start parce fe490cfb00091d186b0039ed1f654a534d4a6a
# Resume fe490cfb00091d186b0039ed1f654a534d4a6a saved in json file
# ********************
# Start parce 808147f00007e2bf5e0039ed1f5732496c6f57
# Resume 808147f00007e2bf5e0039ed1f5732496c6f57 saved in json file
# ********************
# Start parce 32619fe30003da5fbe0039ed1f3268574e6c51
# Resume 32619fe30003da5fbe0039ed1f3268574e6c51 saved in json file
# ********************
# Start parce c7ca7de90008726bd70039ed1f6e70625a434d
# Resume c7ca7de90008726bd70039ed1f6e70625a434d saved in json file
# ********************
# Start parce d94ec71b00075a6e870039ed1f396664524745
# Resume d94ec71b00075a6e870039ed1f396664524745 saved in json file
# ********************
# Start parce e2d757e800072a4e3a0039ed1f533945373745
# Resume e2d757e800072a4e3a0039ed1f533945373745 saved in json file
# ********************
# Start parce 474b424c0007fbf99e0039ed1f634330573633
# Resume 474b424c0007fbf99e0039ed1f634330573633 saved in json file
# ********************
# Start parce d3f4c72b000760b9270039ed1f326b414a3556
# Resume d3f4c72b000760b9270039ed1f326b414a3556 saved in json file
# ********************
# Start parce 32e26e18000828b0c50039ed1f705079504e6c
# Resume 32e26e18000828b0c50039ed1f705079504e6c saved in json file
# ********************
# Start parce ce3cd43c00060f80a10039ed1f4841774f7351
# Resume ce3cd43c00060f80a10039ed1f4841774f7351 saved in json file
# ********************
# Start parce e535e1a000061b60180039ed1f4d7836325656
# Resume e535e1a000061b60180039ed1f4d7836325656 saved in json file
# ********************
# Start parce 9678472c000859ea460039ed1f6669664f356c
# Resume 9678472c000859ea460039ed1f6669664f356c saved in json file
# ********************
# Start parce 3ccedc910007e9c3380039ed1f633074356239
# Resume 3ccedc910007e9c3380039ed1f633074356239 saved in json file
# ********************
# Start parce 1040f8e30006dd294f0039ed1f367868786d59
# Resume 1040f8e30006dd294f0039ed1f367868786d59 saved in json file
# ********************
# Start parce 985b62460002434c710039ed1f575470707170
# Resume 985b62460002434c710039ed1f575470707170 saved in json file
# ********************
# Start parce 77cf03220007e2a9dc0039ed1f304b476f7141
# Resume 77cf03220007e2a9dc0039ed1f304b476f7141 saved in json file
# ********************
# Start parce 667b65af00044991f60039ed1f356778535055
# Resume 667b65af00044991f60039ed1f356778535055 saved in json file
# ********************
# Start parce 4d774bcb000905262b0039ed1f763935703458
# Resume 4d774bcb000905262b0039ed1f763935703458 saved in json file
# ********************
# Start parce 026b8af10003409aba0039ed1f7866676e7553
# Resume 026b8af10003409aba0039ed1f7866676e7553 saved in json file
# ********************
# Start parce 559ada080008311e020039ed1f355374666f62
# Resume 559ada080008311e020039ed1f355374666f62 saved in json file
# ********************
# Start parce 1ced62240007cf524e0039ed1f384b4e546b54
# Resume 1ced62240007cf524e0039ed1f384b4e546b54 saved in json file
# ********************
# Start parce 7bd2ec580008b97be40039ed1f466f6379694e
# Resume 7bd2ec580008b97be40039ed1f466f6379694e saved in json file
# ********************
# Start parce e1f47e0e000693cf660039ed1f666466656474
# Resume e1f47e0e000693cf660039ed1f666466656474 saved in json file
# ********************
# Start parce 7177d32f0008bdb78f0039ed1f61316b304344
# Resume 7177d32f0008bdb78f0039ed1f61316b304344 saved in json file
# ********************
# Start parce e1b52c1d0007ab675d0039ed1f796f35515531
# Resume e1b52c1d0007ab675d0039ed1f796f35515531 saved in json file
# ********************
# Start parce 9843f9c1000337129c0039ed1f764e72735037
# Resume 9843f9c1000337129c0039ed1f764e72735037 saved in json file
# ********************
# Start parce ef5ed24e00024338440039ed1f457551695858
# Resume ef5ed24e00024338440039ed1f457551695858 saved in json file
# ********************
# Start parce 306a826b00059717d60039ed1f4a397174694d
# Resume 306a826b00059717d60039ed1f4a397174694d saved in json file
# ********************
# Start parce 337d3a1100090de7ae0039ed1f42587a735164
# Resume 337d3a1100090de7ae0039ed1f42587a735164 saved in json file
# ********************
# Start parce fb43976700030b5f9d0039ed1f46536e4b546f
# Resume fb43976700030b5f9d0039ed1f46536e4b546f saved in json file
# ********************
# Start parce cd06223900092f8afe0039ed1f59516144727a
# Resume cd06223900092f8afe0039ed1f59516144727a saved in json file
# ********************
# Start parce afa811f5000171ae080039ed1f59467335725a
# Resume afa811f5000171ae080039ed1f59467335725a saved in json file
# ********************
# Start parce d303b83400041ab52a0039ed1f5971346c3174
# Resume d303b83400041ab52a0039ed1f5971346c3174 saved in json file
# ********************
# Start parce 5d16739d0008fc1e2a0039ed1f617835547937
# Resume 5d16739d0008fc1e2a0039ed1f617835547937 saved in json file
# ********************
# Start parce 147b732a0008830dec0039ed1f546e78536f45
# Resume 147b732a0008830dec0039ed1f546e78536f45 saved in json file
# ********************
# Start parce aa30d950000908a7a30039ed1f62474e506d79
# Resume aa30d950000908a7a30039ed1f62474e506d79 saved in json file
# ********************
# Start parce 39d3fb650007ebc6ed0039ed1f756e6c726f72
# Resume 39d3fb650007ebc6ed0039ed1f756e6c726f72 saved in json file
# ********************
# Start parce 3a6ddf8700071390e30039ed1f464c31574c34
# Resume 3a6ddf8700071390e30039ed1f464c31574c34 saved in json file
# ********************
# Start parce e72bb1f2000720e8140039ed1f444e494c7945
# Resume e72bb1f2000720e8140039ed1f444e494c7945 saved in json file
# ********************
# Start parce d95871db00042e30be0039ed1f773976373051
# Resume d95871db00042e30be0039ed1f773976373051 saved in json file
# ********************
# Start parce f4f2bed50005a7d6eb0039ed1f4a6d76794c56
# Resume f4f2bed50005a7d6eb0039ed1f4a6d76794c56 saved in json file
# ********************
# Start parce 302ccf1600085ae37b0039ed1f6472594d7134
# Resume 302ccf1600085ae37b0039ed1f6472594d7134 saved in json file
# ********************
# Start parce b9637b2c0008d384c10039ed1f4e4b72516f31
# Resume b9637b2c0008d384c10039ed1f4e4b72516f31 saved in json file
# ********************
# Start parce 06e786be0008358f850039ed1f4c4356666550
# Resume 06e786be0008358f850039ed1f4c4356666550 saved in json file
# ********************
# Start parce dadb96de00079afd900039ed1f364c4c695a69
# Resume dadb96de00079afd900039ed1f364c4c695a69 saved in json file
# ********************
# Start parce 4caac8e80008fd8a130039ed1f305451724743
# Resume 4caac8e80008fd8a130039ed1f305451724743 saved in json file
# ********************
# Start parce 42c008a900029d198e0039ed1f4e4378306f4e
# Resume 42c008a900029d198e0039ed1f4e4378306f4e saved in json file
# ********************
# Start parce 842edaa30008493f7d0039ed1f57334f767759
# Resume 842edaa30008493f7d0039ed1f57334f767759 saved in json file
# ********************
# Start parce 3b77e23100028232e80039ed1f556a6d484f56
# Resume 3b77e23100028232e80039ed1f556a6d484f56 saved in json file
# ********************
# Start parce b0ddc13d00061ce7170039ed1f436c4f477035
# Resume b0ddc13d00061ce7170039ed1f436c4f477035 saved in json file
# ********************
# Start parce dfe0c813000867787b0039ed1f734a694a5061
# Resume dfe0c813000867787b0039ed1f734a694a5061 saved in json file
# ********************
# Start parce d7844f79000287eef80039ed1f6e395155546a
# Resume d7844f79000287eef80039ed1f6e395155546a saved in json file
# ********************
# Start parce b534e9dd0001fb7cba0039ed1f45694f626d6b
# Resume b534e9dd0001fb7cba0039ed1f45694f626d6b saved in json file
# ********************
# Start parce eb6fe2b6000459c7b10039ed1f6f4e58647945
# Resume eb6fe2b6000459c7b10039ed1f6f4e58647945 saved in json file
# ********************
# Start parce 2327309f0008a2a0670039ed1f4d6274515945
# Resume 2327309f0008a2a0670039ed1f4d6274515945 saved in json file
# ********************
# Start parce f185804c0007ab14b30039ed1f465a56395669
# Resume f185804c0007ab14b30039ed1f465a56395669 saved in json file
# ********************
# Start parce 24b4bb300003a5c7b00039ed1f6a4f4377674a
# Resume 24b4bb300003a5c7b00039ed1f6a4f4377674a saved in json file
# ********************
# Start parce c7d13dd20003a0b92c0039ed1f42714c36564b
# Resume c7d13dd20003a0b92c0039ed1f42714c36564b saved in json file
# ********************
# Start parce 5f39ca3b0008a0662f0039ed1f474b55453751
# Resume 5f39ca3b0008a0662f0039ed1f474b55453751 saved in json file
# ********************
# Start parce 584d67300006000ca50039ed1f75523942506d
# Resume 584d67300006000ca50039ed1f75523942506d saved in json file
# ********************
# Start parce 65dc4f7000083c9bb60039ed1f5241336a7a35
# Resume 65dc4f7000083c9bb60039ed1f5241336a7a35 saved in json file
# ********************
# Start parce 115faa9900088041ba0039ed1f6949324d7554
# Resume 115faa9900088041ba0039ed1f6949324d7554 saved in json file
# ********************
# Start parce 3f3831d10007bb50ec0039ed1f59566b436463
# Resume 3f3831d10007bb50ec0039ed1f59566b436463 saved in json file
# ********************
# Start parce 7ef4288000043bb26e0039ed1f6e5761666c53
# Resume 7ef4288000043bb26e0039ed1f6e5761666c53 saved in json file
# ********************
# Start parce 518e3cff000714ac9a0039ed1f55616b4f7a69
# Resume 518e3cff000714ac9a0039ed1f55616b4f7a69 saved in json file
# ********************
# Start parce b2603fc70003036c380039ed1f6e36696e714b
# Resume b2603fc70003036c380039ed1f6e36696e714b saved in json file
# ********************
# Start parce 857d2bf700087025f90039ed1f355036447243
# Resume 857d2bf700087025f90039ed1f355036447243 saved in json file
# ********************
# Start parce b0d83207000859eef60039ed1f30667964316c
# Resume b0d83207000859eef60039ed1f30667964316c saved in json file
# ********************
# Start parce 2762cb240002b521550039ed1f644431366678
# Resume 2762cb240002b521550039ed1f644431366678 saved in json file
# ********************
# Start parce 054e2e11000317f8760039ed1f5a586b423563
# Resume 054e2e11000317f8760039ed1f5a586b423563 saved in json file
# ********************
# Start parce fdc1480d0008ab9e360039ed1f33526c4a6431
# Resume fdc1480d0008ab9e360039ed1f33526c4a6431 saved in json file
# ********************
# Start parce e92e61e80004472b930039ed1f7a624c417439
# Resume e92e61e80004472b930039ed1f7a624c417439 saved in json file
# ********************
# Start parce 3d5ac18f0007da71dd0039ed1f684d30307257
# Resume 3d5ac18f0007da71dd0039ed1f684d30307257 saved in json file
# ********************
# Start parce 1c4975c10003c9cedf0039ed1f4234394a5256
# Resume 1c4975c10003c9cedf0039ed1f4234394a5256 saved in json file
# ********************
# Start parce df3860470003de34f50039ed1f30663572426b
# Resume df3860470003de34f50039ed1f30663572426b saved in json file
# ********************
# Start parce 3262041d0000a6199c0039ed1f736563726574
# Resume 3262041d0000a6199c0039ed1f736563726574 saved in json file
# ********************
# Start parce fed2d039000809849e0039ed1f757a72514935
# Resume fed2d039000809849e0039ed1f757a72514935 saved in json file
# ********************

# %%
df = pd.DataFrame(all_resumes)
df.to_csv('/content/drive/MyDrive/Дипломная работа/Данные из резюме.csv', encoding = 'utf-8', sep=',')

# %%
df = pd.DataFrame(all_resumes)
df.to_pickle("/content/drive/MyDrive/Дипломная работа/Данные резюме.pkl")
